# %% [markdown]
# ## Selecting a deep learning model with MLP

# %% [markdown]
# Next step for our research is deep learning. For this stage we try using **MLP model** with keras.

# %% [markdown]
# ####  Import libraries,  import custom scripts and define constants

# %%
from __future__ import print_function
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import f1_score

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping, TensorBoard, ModelCheckpoint
from tensorflow.keras.optimizers import Adam

import tensorflow.keras.backend as K

from tensorflow.keras.preprocessing.text import text_to_word_sequence
from sklearn.model_selection import train_test_split


import re

# %%
import os,sys,inspect
currentdir=os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir=os.path.dirname(currentdir)
sys.path.insert(0,parentdir)
from src import preprocessing

# %%
#definition constants
RANDOM_STATE = 11
TARGET_METRIC = 'f1'
TEST_SIZE = 0.15

# %% [markdown]
# ####  Loading the data

# %%
# import & display data
data = pd.read_csv('../../data/IMDB_Dataset.csv')
data['sentiment'] = data['sentiment'].replace({'positive' : 1, 'negative' : 0})
data = data.drop_duplicates()
data.head()
# Out:
#                                               review  sentiment
# 0  One of the other reviewers has mentioned that ...          1
# 1  A wonderful little production. <br /><br />The...          1
# 2  I thought this was a wonderful way to spend ti...          1
# 3  Basically there's a family where a little boy ...          0
# 4  Petter Mattei's "Love in the Time of Money" is...          1

# %% [markdown]
# ####  Split data for training, testing and validation sets

# %%
X = data.review
y = data.sentiment
X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y,
                                                    test_size=TEST_SIZE, 
                                                    random_state=RANDOM_STATE, 
                                                    stratify = y)
X_train, X_valid, y_train, y_valid = train_test_split(X_train, 
                                                    y_train,
                                                    test_size=TEST_SIZE, 
                                                    random_state=RANDOM_STATE, 
                                                    stratify = y_train)

# %% [markdown]
# #### Preprocessing Data

# %% [markdown]
# For pre-processing and vectorization, let's use the approach from the previous stage, which received the best performance.
#
# For pre-processing:
# * the removal of html-tags,
# * the separation of numbers and letters.
#
# For vectorization we use  `TfidfVectorizer(ngram_range=(1,2))`

# %%
MAX_FEATURES = 20000

vectorizer = TfidfVectorizer(ngram_range=(1,2), preprocessor=preprocessing.preprocessing_text, max_features=MAX_FEATURES)

vectorizer.fit(X_train)
X_train_features = vectorizer.transform(X_train)
X_valid_features = vectorizer.transform(X_valid)
X_test_features = vectorizer.transform(X_test)

# %% [markdown]
# #### Creating the model
# Define the function for create the simple MLP model

# %%
def mlp_model(layers, units, dropout_rate, input_shape):
    model = Sequential()
    model.add(Dropout(rate=dropout_rate, input_shape=input_shape))
    for _ in range(layers-1):
        model.add(Dense(units=units, activation='relu'))
        model.add(Dropout(rate=dropout_rate))
    model.add(Dense(1, activation='sigmoid'))
    return model

# %%
#function for f1 metric
def get_f1(y_true, y_pred): 
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

# %% [markdown]
# Define the function for training the model

# %%
def train_model(data,
                learning_rate=1e-3,
                epochs=100,
                batch_size=128,
                layers=2,
                units=32,
                dropout_rate=0.3,
               filepath='model.hdf5',
                log_dir='logs/mlp1/fit'):
    # Get the data.
    (x_train, train_labels), (x_val, val_labels) = data

    # Create model instance.
    K.clear_session()
    model = mlp_model(layers=layers,
                                  units=units,
                                  dropout_rate=dropout_rate,
                                  input_shape=x_train.shape[1:])

    # Compile model with learning parameters.
    loss = 'binary_crossentropy'
    optimizer = Adam(lr=learning_rate)
    model.compile(optimizer=optimizer, loss=loss, metrics=[get_f1])

    # Create callback for early stopping on validation loss. 
    tensorboard_callback = TensorBoard(log_dir=log_dir, histogram_freq=1)
    early_stop = EarlyStopping(monitor='val_loss', 
                           patience=3)
    cp_callback = ModelCheckpoint(filepath=filepath,
                              save_best_only=True,
                              verbose=1)
    callbacks = [cp_callback, early_stop, tensorboard_callback]
    
    model.summary()
    
    # Train and validate model.
    history = model.fit(
            x_train,
            train_labels,
            epochs=epochs,
            callbacks=callbacks,
            validation_data=(x_val, val_labels),
            verbose=2,  # Logs once per epoch.
            batch_size=batch_size)

    return history

# %% [markdown]
# #### Train different models and save result

# %% [markdown]
# Model1:
# * learning_rate=1e-3,
# * epochs=100,
# * batch_size=128,
# * layers=1,
# * units=32,
# * dropout_rate=0.3.

# %%
result1 = train_model(((X_train_features,y_train), (X_valid_features, y_valid)),
                    filepath='models/model1.hdf5',
                      layers=1,
                     log_dir='logs/mlp_5_5/model1')
# Out:
# WARNING:tensorflow:From C:\Users\Tatsiana_Drabysheusk\AppData\Local\Continuum\miniconda3\envs\Project_New\lib\site-packages\tensorflow\python\keras\layers\core.py:143: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From C:\Users\Tatsiana_Drabysheusk\AppData\Local\Continuum\miniconda3\envs\Project_New\lib\site-packages\tensorflow\python\ops\control_flow_ops.py:423: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dropout (Dropout)            (None, 20000)             0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 20001
# =================================================================
# Total params: 20,001
# Trainable params: 20,001
# Non-trainable params: 0
# _________________________________________________________________
# Train on 35822 samples, validate on 6322 samples
# WARNING:tensorflow:From C:\Users\Tatsiana_Drabysheusk\AppData\Local\Continuum\miniconda3\envs\Project_New\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/100
#
# Epoch 00001: val_loss improved from inf to 0.61387, saving model to models/model1.hdf5
#  - 15s - loss: 0.6527 - get_f1: 0.7689 - val_loss: 0.6139 - val_get_f1: 0.8632
# Epoch 2/100
#
# Epoch 00002: val_loss improved from 0.61387 to 0.55469, saving model to models/model1.hdf5
#  - 14s - loss: 0.5824 - get_f1: 0.8565 - val_loss: 0.5547 - val_get_f1: 0.8669
# Epoch 3/100
#
# Epoch 00003: val_loss improved from 0.55469 to 0.50902, saving model to models/model1.hdf5
#  - 14s - loss: 0.5289 - get_f1: 0.8656 - val_loss: 0.5090 - val_get_f1: 0.8768
# Epoch 4/100
#
# Epoch 00004: val_loss improved from 0.50902 to 0.47289, saving model to models/model1.hdf5
#  - 15s - loss: 0.4880 - get_f1: 0.8721 - val_loss: 0.4729 - val_get_f1: 0.8834
# Epoch 5/100
#
# Epoch 00005: val_loss improved from 0.47289 to 0.44357, saving model to models/model1.hdf5
#  - 14s - loss: 0.4544 - get_f1: 0.8793 - val_loss: 0.4436 - val_get_f1: 0.8873
# Epoch 6/100
#
# Epoch 00006: val_loss improved from 0.44357 to 0.41942, saving model to models/model1.hdf5
#  - 14s - loss: 0.4275 - get_f1: 0.8819 - val_loss: 0.4194 - val_get_f1: 0.8901
# Epoch 7/100
#
# Epoch 00007: val_loss improved from 0.41942 to 0.39910, saving model to models/model1.hdf5
#  - 14s - loss: 0.4041 - get_f1: 0.8868 - val_loss: 0.3991 - val_get_f1: 0.8913
# Epoch 8/100
#
# Epoch 00008: val_loss improved from 0.39910 to 0.38185, saving model to models/model1.hdf5
#  - 15s - loss: 0.3853 - get_f1: 0.8897 - val_loss: 0.3819 - val_get_f1: 0.8932
# Epoch 9/100
#
# Epoch 00009: val_loss improved from 0.38185 to 0.36692, saving model to models/model1.hdf5
#  - 14s - loss: 0.3677 - get_f1: 0.8943 - val_loss: 0.3669 - val_get_f1: 0.8945
# Epoch 10/100
#
# Epoch 00010: val_loss improved from 0.36692 to 0.35391, saving model to models/model1.hdf5
#  - 14s - loss: 0.3537 - get_f1: 0.8970 - val_loss: 0.3539 - val_get_f1: 0.8974
# Epoch 11/100
#
# Epoch 00011: val_loss improved from 0.35391 to 0.34250, saving model to models/model1.hdf5
#  - 14s - loss: 0.3408 - get_f1: 0.8993 - val_loss: 0.3425 - val_get_f1: 0.8989
# Epoch 12/100
#
# Epoch 00012: val_loss improved from 0.34250 to 0.33242, saving model to models/model1.hdf5
#  - 14s - loss: 0.3299 - get_f1: 0.9014 - val_loss: 0.3324 - val_get_f1: 0.9018
# Epoch 13/100
#
# Epoch 00013: val_loss improved from 0.33242 to 0.32343, saving model to models/model1.hdf5
#  - 14s - loss: 0.3185 - get_f1: 0.9040 - val_loss: 0.3234 - val_get_f1: 0.9018
# Epoch 14/100
#
# Epoch 00014: val_loss improved from 0.32343 to 0.31531, saving model to models/model1.hdf5
#  - 14s - loss: 0.3098 - get_f1: 0.9061 - val_loss: 0.3153 - val_get_f1: 0.9037
# Epoch 15/100
#
# Epoch 00015: val_loss improved from 0.31531 to 0.30806, saving model to models/model1.hdf5
#  - 14s - loss: 0.3009 - get_f1: 0.9083 - val_loss: 0.3081 - val_get_f1: 0.9054
# Epoch 16/100
#
# Epoch 00016: val_loss improved from 0.30806 to 0.30152, saving model to models/model1.hdf5
#  - 14s - loss: 0.2933 - get_f1: 0.9096 - val_loss: 0.3015 - val_get_f1: 0.9069
# Epoch 17/100
#
# Epoch 00017: val_loss improved from 0.30152 to 0.29554, saving model to models/model1.hdf5
#  - 14s - loss: 0.2862 - get_f1: 0.9115 - val_loss: 0.2955 - val_get_f1: 0.9087
# Epoch 18/100
#
# Epoch 00018: val_loss improved from 0.29554 to 0.29012, saving model to models/model1.hdf5
#  - 14s - loss: 0.2804 - get_f1: 0.9118 - val_loss: 0.2901 - val_get_f1: 0.9091
# Epoch 19/100
#
# Epoch 00019: val_loss improved from 0.29012 to 0.28516, saving model to models/model1.hdf5
#  - 14s - loss: 0.2735 - get_f1: 0.9152 - val_loss: 0.2852 - val_get_f1: 0.9087
# Epoch 20/100
#
# Epoch 00020: val_loss improved from 0.28516 to 0.28068, saving model to models/model1.hdf5
#  - 14s - loss: 0.2685 - get_f1: 0.9149 - val_loss: 0.2807 - val_get_f1: 0.9107
# Epoch 21/100
#
# Epoch 00021: val_loss improved from 0.28068 to 0.27645, saving model to models/model1.hdf5
#  - 14s - loss: 0.2633 - get_f1: 0.9180 - val_loss: 0.2765 - val_get_f1: 0.9123
# Epoch 22/100
#
# Epoch 00022: val_loss improved from 0.27645 to 0.27257, saving model to models/model1.hdf5
#  - 14s - loss: 0.2585 - get_f1: 0.9185 - val_loss: 0.2726 - val_get_f1: 0.9144
# Epoch 23/100
#
# Epoch 00023: val_loss improved from 0.27257 to 0.26899, saving model to models/model1.hdf5
#  - 14s - loss: 0.2530 - get_f1: 0.9203 - val_loss: 0.2690 - val_get_f1: 0.9142
# Epoch 24/100
#
# Epoch 00024: val_loss improved from 0.26899 to 0.26572, saving model to models/model1.hdf5
#  - 14s - loss: 0.2486 - get_f1: 0.9214 - val_loss: 0.2657 - val_get_f1: 0.9147
# Epoch 25/100
#
# Epoch 00025: val_loss improved from 0.26572 to 0.26263, saving model to models/model1.hdf5
#  - 14s - loss: 0.2459 - get_f1: 0.9210 - val_loss: 0.2626 - val_get_f1: 0.9153
# Epoch 26/100
#
# Epoch 00026: val_loss improved from 0.26263 to 0.25980, saving model to models/model1.hdf5
#  - 14s - loss: 0.2411 - get_f1: 0.9235 - val_loss: 0.2598 - val_get_f1: 0.9164
# Epoch 27/100
#
# Epoch 00027: val_loss improved from 0.25980 to 0.25721, saving model to models/model1.hdf5
#  - 14s - loss: 0.2379 - get_f1: 0.9245 - val_loss: 0.2572 - val_get_f1: 0.9163
# Epoch 28/100
#
# Epoch 00028: val_loss improved from 0.25721 to 0.25470, saving model to models/model1.hdf5
#  - 14s - loss: 0.2343 - get_f1: 0.9250 - val_loss: 0.2547 - val_get_f1: 0.9172
# Epoch 29/100
#
# Epoch 00029: val_loss improved from 0.25470 to 0.25244, saving model to models/model1.hdf5
#  - 14s - loss: 0.2325 - get_f1: 0.9259 - val_loss: 0.2524 - val_get_f1: 0.9159
# Epoch 30/100
#
# Epoch 00030: val_loss improved from 0.25244 to 0.25032, saving model to models/model1.hdf5
#  - 14s - loss: 0.2284 - get_f1: 0.9266 - val_loss: 0.2503 - val_get_f1: 0.9170
# Epoch 31/100
#
# Epoch 00031: val_loss improved from 0.25032 to 0.24827, saving model to models/model1.hdf5
#  - 14s - loss: 0.2265 - get_f1: 0.9259 - val_loss: 0.2483 - val_get_f1: 0.9180
# Epoch 32/100
#
# Epoch 00032: val_loss improved from 0.24827 to 0.24635, saving model to models/model1.hdf5
#  - 14s - loss: 0.2236 - get_f1: 0.9271 - val_loss: 0.2463 - val_get_f1: 0.9180
# Epoch 33/100
#
# Epoch 00033: val_loss improved from 0.24635 to 0.24460, saving model to models/model1.hdf5
#  - 14s - loss: 0.2210 - get_f1: 0.9276 - val_loss: 0.2446 - val_get_f1: 0.9155
# Epoch 34/100
#
# Epoch 00034: val_loss improved from 0.24460 to 0.24290, saving model to models/model1.hdf5
#  - 14s - loss: 0.2182 - get_f1: 0.9293 - val_loss: 0.2429 - val_get_f1: 0.9181
# Epoch 35/100
#
# Epoch 00035: val_loss improved from 0.24290 to 0.24129, saving model to models/model1.hdf5
#  - 14s - loss: 0.2166 - get_f1: 0.9288 - val_loss: 0.2413 - val_get_f1: 0.9176
# Epoch 36/100
#
# Epoch 00036: val_loss improved from 0.24129 to 0.23981, saving model to models/model1.hdf5
#  - 15s - loss: 0.2149 - get_f1: 0.9288 - val_loss: 0.2398 - val_get_f1: 0.9180
# Epoch 37/100
#
# Epoch 00037: val_loss improved from 0.23981 to 0.23846, saving model to models/model1.hdf5
#  - 14s - loss: 0.2117 - get_f1: 0.9310 - val_loss: 0.2385 - val_get_f1: 0.9183
# Epoch 38/100
#
# Epoch 00038: val_loss improved from 0.23846 to 0.23711, saving model to models/model1.hdf5
#  - 14s - loss: 0.2088 - get_f1: 0.9312 - val_loss: 0.2371 - val_get_f1: 0.9184
# Epoch 39/100
#
# Epoch 00039: val_loss improved from 0.23711 to 0.23591, saving model to models/model1.hdf5
#  - 14s - loss: 0.2069 - get_f1: 0.9324 - val_loss: 0.2359 - val_get_f1: 0.9191
# Epoch 40/100
#
# Epoch 00040: val_loss improved from 0.23591 to 0.23480, saving model to models/model1.hdf5
#  - 14s - loss: 0.2047 - get_f1: 0.9333 - val_loss: 0.2348 - val_get_f1: 0.9192
# Epoch 41/100
#
# Epoch 00041: val_loss improved from 0.23480 to 0.23374, saving model to models/model1.hdf5
#  - 14s - loss: 0.2023 - get_f1: 0.9337 - val_loss: 0.2337 - val_get_f1: 0.9184
# Epoch 42/100
#
# Epoch 00042: val_loss improved from 0.23374 to 0.23266, saving model to models/model1.hdf5
#  - 14s - loss: 0.2007 - get_f1: 0.9349 - val_loss: 0.2327 - val_get_f1: 0.9195
# Epoch 43/100
#
# Epoch 00043: val_loss improved from 0.23266 to 0.23170, saving model to models/model1.hdf5
#  - 14s - loss: 0.1986 - get_f1: 0.9357 - val_loss: 0.2317 - val_get_f1: 0.9199
# Epoch 44/100
#
# Epoch 00044: val_loss improved from 0.23170 to 0.23074, saving model to models/model1.hdf5
#  - 14s - loss: 0.1971 - get_f1: 0.9358 - val_loss: 0.2307 - val_get_f1: 0.9196
# Epoch 45/100
#
# Epoch 00045: val_loss improved from 0.23074 to 0.22981, saving model to models/model1.hdf5
#  - 14s - loss: 0.1964 - get_f1: 0.9355 - val_loss: 0.2298 - val_get_f1: 0.9197
# Epoch 46/100
#
# Epoch 00046: val_loss improved from 0.22981 to 0.22889, saving model to models/model1.hdf5
#  - 14s - loss: 0.1948 - get_f1: 0.9359 - val_loss: 0.2289 - val_get_f1: 0.9193
# Epoch 47/100
#
# Epoch 00047: val_loss improved from 0.22889 to 0.22808, saving model to models/model1.hdf5
#  - 14s - loss: 0.1917 - get_f1: 0.9391 - val_loss: 0.2281 - val_get_f1: 0.9192
# Epoch 48/100
#
# Epoch 00048: val_loss improved from 0.22808 to 0.22737, saving model to models/model1.hdf5
#  - 15s - loss: 0.1905 - get_f1: 0.9381 - val_loss: 0.2274 - val_get_f1: 0.9196
# Epoch 49/100
#
# Epoch 00049: val_loss improved from 0.22737 to 0.22653, saving model to models/model1.hdf5
#  - 14s - loss: 0.1896 - get_f1: 0.9382 - val_loss: 0.2265 - val_get_f1: 0.9191
# Epoch 50/100
#
# Epoch 00050: val_loss improved from 0.22653 to 0.22577, saving model to models/model1.hdf5
#  - 14s - loss: 0.1876 - get_f1: 0.9384 - val_loss: 0.2258 - val_get_f1: 0.9200
# Epoch 51/100
#
# Epoch 00051: val_loss improved from 0.22577 to 0.22517, saving model to models/model1.hdf5
#  - 14s - loss: 0.1868 - get_f1: 0.9395 - val_loss: 0.2252 - val_get_f1: 0.9200
# Epoch 52/100
#
# Epoch 00052: val_loss improved from 0.22517 to 0.22454, saving model to models/model1.hdf5
#  - 15s - loss: 0.1862 - get_f1: 0.9383 - val_loss: 0.2245 - val_get_f1: 0.9192
# Epoch 53/100
#
# Epoch 00053: val_loss improved from 0.22454 to 0.22396, saving model to models/model1.hdf5
#  - 14s - loss: 0.1833 - get_f1: 0.9410 - val_loss: 0.2240 - val_get_f1: 0.9203
# Epoch 54/100
#
# Epoch 00054: val_loss improved from 0.22396 to 0.22333, saving model to models/model1.hdf5
#  - 14s - loss: 0.1823 - get_f1: 0.9401 - val_loss: 0.2233 - val_get_f1: 0.9190
# Epoch 55/100
#
# Epoch 00055: val_loss improved from 0.22333 to 0.22270, saving model to models/model1.hdf5
#  - 14s - loss: 0.1815 - get_f1: 0.9405 - val_loss: 0.2227 - val_get_f1: 0.9198
# Epoch 56/100
#
# Epoch 00056: val_loss improved from 0.22270 to 0.22221, saving model to models/model1.hdf5
#  - 14s - loss: 0.1812 - get_f1: 0.9412 - val_loss: 0.2222 - val_get_f1: 0.9191
# Epoch 57/100
#
# Epoch 00057: val_loss improved from 0.22221 to 0.22169, saving model to models/model1.hdf5
#  - 15s - loss: 0.1790 - get_f1: 0.9415 - val_loss: 0.2217 - val_get_f1: 0.9199
# Epoch 58/100
#
# Epoch 00058: val_loss improved from 0.22169 to 0.22120, saving model to models/model1.hdf5
#  - 14s - loss: 0.1779 - get_f1: 0.9411 - val_loss: 0.2212 - val_get_f1: 0.9209
# Epoch 59/100
#
# Epoch 00059: val_loss improved from 0.22120 to 0.22078, saving model to models/model1.hdf5
#  - 15s - loss: 0.1780 - get_f1: 0.9414 - val_loss: 0.2208 - val_get_f1: 0.9200
# Epoch 60/100
#
# Epoch 00060: val_loss improved from 0.22078 to 0.22032, saving model to models/model1.hdf5
#  - 14s - loss: 0.1758 - get_f1: 0.9420 - val_loss: 0.2203 - val_get_f1: 0.9196
# Epoch 61/100
#
# Epoch 00061: val_loss improved from 0.22032 to 0.21994, saving model to models/model1.hdf5
#  - 14s - loss: 0.1748 - get_f1: 0.9423 - val_loss: 0.2199 - val_get_f1: 0.9208
# Epoch 62/100
#
# Epoch 00062: val_loss improved from 0.21994 to 0.21951, saving model to models/model1.hdf5
#  - 14s - loss: 0.1727 - get_f1: 0.9448 - val_loss: 0.2195 - val_get_f1: 0.9207
# Epoch 63/100
#
# Epoch 00063: val_loss improved from 0.21951 to 0.21911, saving model to models/model1.hdf5
#  - 14s - loss: 0.1724 - get_f1: 0.9438 - val_loss: 0.2191 - val_get_f1: 0.9208
# Epoch 64/100
#
# Epoch 00064: val_loss improved from 0.21911 to 0.21875, saving model to models/model1.hdf5
#  - 14s - loss: 0.1685 - get_f1: 0.9455 - val_loss: 0.2188 - val_get_f1: 0.9208
# Epoch 65/100
#
# Epoch 00065: val_loss improved from 0.21875 to 0.21839, saving model to models/model1.hdf5
#  - 14s - loss: 0.1695 - get_f1: 0.9449 - val_loss: 0.2184 - val_get_f1: 0.9203
# Epoch 66/100
#
# Epoch 00066: val_loss improved from 0.21839 to 0.21804, saving model to models/model1.hdf5
#  - 14s - loss: 0.1695 - get_f1: 0.9458 - val_loss: 0.2180 - val_get_f1: 0.9208
# Epoch 67/100
#
# Epoch 00067: val_loss improved from 0.21804 to 0.21774, saving model to models/model1.hdf5
#  - 14s - loss: 0.1667 - get_f1: 0.9463 - val_loss: 0.2177 - val_get_f1: 0.9204
# Epoch 68/100
#
# Epoch 00068: val_loss improved from 0.21774 to 0.21745, saving model to models/model1.hdf5
#  - 15s - loss: 0.1669 - get_f1: 0.9464 - val_loss: 0.2175 - val_get_f1: 0.9207
# Epoch 69/100
#
# Epoch 00069: val_loss improved from 0.21745 to 0.21719, saving model to models/model1.hdf5
#  - 14s - loss: 0.1665 - get_f1: 0.9454 - val_loss: 0.2172 - val_get_f1: 0.9201
# Epoch 70/100
#
# Epoch 00070: val_loss improved from 0.21719 to 0.21693, saving model to models/model1.hdf5
#  - 14s - loss: 0.1678 - get_f1: 0.9454 - val_loss: 0.2169 - val_get_f1: 0.9213
# Epoch 71/100
#
# Epoch 00071: val_loss improved from 0.21693 to 0.21663, saving model to models/model1.hdf5
#  - 15s - loss: 0.1628 - get_f1: 0.9472 - val_loss: 0.2166 - val_get_f1: 0.9204
# Epoch 72/100
#
# Epoch 00072: val_loss improved from 0.21663 to 0.21648, saving model to models/model1.hdf5
#  - 14s - loss: 0.1654 - get_f1: 0.9453 - val_loss: 0.2165 - val_get_f1: 0.9194
# Epoch 73/100
#
# Epoch 00073: val_loss improved from 0.21648 to 0.21621, saving model to models/model1.hdf5
#  - 14s - loss: 0.1625 - get_f1: 0.9465 - val_loss: 0.2162 - val_get_f1: 0.9208
# Epoch 74/100
#
# Epoch 00074: val_loss improved from 0.21621 to 0.21595, saving model to models/model1.hdf5
#  - 14s - loss: 0.1631 - get_f1: 0.9470 - val_loss: 0.2159 - val_get_f1: 0.9203
# Epoch 75/100
#
# Epoch 00075: val_loss improved from 0.21595 to 0.21577, saving model to models/model1.hdf5
#  - 14s - loss: 0.1609 - get_f1: 0.9479 - val_loss: 0.2158 - val_get_f1: 0.9219
# Epoch 76/100
#
# Epoch 00076: val_loss improved from 0.21577 to 0.21554, saving model to models/model1.hdf5
#  - 14s - loss: 0.1610 - get_f1: 0.9479 - val_loss: 0.2155 - val_get_f1: 0.9195
# Epoch 77/100
#
# Epoch 00077: val_loss improved from 0.21554 to 0.21538, saving model to models/model1.hdf5
#  - 14s - loss: 0.1601 - get_f1: 0.9475 - val_loss: 0.2154 - val_get_f1: 0.9206
# Epoch 78/100
#
# Epoch 00078: val_loss improved from 0.21538 to 0.21521, saving model to models/model1.hdf5
#  - 14s - loss: 0.1588 - get_f1: 0.9472 - val_loss: 0.2152 - val_get_f1: 0.9207
# Epoch 79/100
#
# Epoch 00079: val_loss improved from 0.21521 to 0.21504, saving model to models/model1.hdf5
#  - 14s - loss: 0.1565 - get_f1: 0.9490 - val_loss: 0.2150 - val_get_f1: 0.9195
# Epoch 80/100
#
# Epoch 00080: val_loss improved from 0.21504 to 0.21488, saving model to models/model1.hdf5
#  - 14s - loss: 0.1568 - get_f1: 0.9494 - val_loss: 0.2149 - val_get_f1: 0.9205
# Epoch 81/100
#
# Epoch 00081: val_loss improved from 0.21488 to 0.21472, saving model to models/model1.hdf5
#  - 14s - loss: 0.1561 - get_f1: 0.9495 - val_loss: 0.2147 - val_get_f1: 0.9190
# Epoch 82/100
#
# Epoch 00082: val_loss improved from 0.21472 to 0.21456, saving model to models/model1.hdf5
#  - 15s - loss: 0.1559 - get_f1: 0.9493 - val_loss: 0.2146 - val_get_f1: 0.9197
# Epoch 83/100
#
# Epoch 00083: val_loss improved from 0.21456 to 0.21437, saving model to models/model1.hdf5
#  - 14s - loss: 0.1555 - get_f1: 0.9498 - val_loss: 0.2144 - val_get_f1: 0.9203
# Epoch 84/100
#
# Epoch 00084: val_loss improved from 0.21437 to 0.21428, saving model to models/model1.hdf5
#  - 14s - loss: 0.1555 - get_f1: 0.9501 - val_loss: 0.2143 - val_get_f1: 0.9205
# Epoch 85/100
#
# Epoch 00085: val_loss improved from 0.21428 to 0.21412, saving model to models/model1.hdf5
#  - 15s - loss: 0.1531 - get_f1: 0.9498 - val_loss: 0.2141 - val_get_f1: 0.9196
# Epoch 86/100
#
# Epoch 00086: val_loss improved from 0.21412 to 0.21411, saving model to models/model1.hdf5
#  - 14s - loss: 0.1535 - get_f1: 0.9499 - val_loss: 0.2141 - val_get_f1: 0.9197
# Epoch 87/100
#
# Epoch 00087: val_loss improved from 0.21411 to 0.21391, saving model to models/model1.hdf5
#  - 15s - loss: 0.1518 - get_f1: 0.9503 - val_loss: 0.2139 - val_get_f1: 0.9201
# Epoch 88/100
#
# Epoch 00088: val_loss improved from 0.21391 to 0.21376, saving model to models/model1.hdf5
#  - 14s - loss: 0.1521 - get_f1: 0.9502 - val_loss: 0.2138 - val_get_f1: 0.9192
# Epoch 89/100
#
# Epoch 00089: val_loss improved from 0.21376 to 0.21359, saving model to models/model1.hdf5
#  - 14s - loss: 0.1506 - get_f1: 0.9512 - val_loss: 0.2136 - val_get_f1: 0.9206
# Epoch 90/100
#
# Epoch 00090: val_loss improved from 0.21359 to 0.21356, saving model to models/model1.hdf5
#  - 14s - loss: 0.1490 - get_f1: 0.9527 - val_loss: 0.2136 - val_get_f1: 0.9212
# Epoch 91/100
#
# Epoch 00091: val_loss improved from 0.21356 to 0.21338, saving model to models/model1.hdf5
#  - 15s - loss: 0.1505 - get_f1: 0.9510 - val_loss: 0.2134 - val_get_f1: 0.9200
# Epoch 92/100
#
# Epoch 00092: val_loss improved from 0.21338 to 0.21335, saving model to models/model1.hdf5
#  - 14s - loss: 0.1504 - get_f1: 0.9516 - val_loss: 0.2133 - val_get_f1: 0.9198
# Epoch 93/100
#
# Epoch 00093: val_loss improved from 0.21335 to 0.21330, saving model to models/model1.hdf5
#  - 14s - loss: 0.1484 - get_f1: 0.9520 - val_loss: 0.2133 - val_get_f1: 0.9205
# Epoch 94/100
#
# Epoch 00094: val_loss improved from 0.21330 to 0.21327, saving model to models/model1.hdf5
#  - 14s - loss: 0.1482 - get_f1: 0.9513 - val_loss: 0.2133 - val_get_f1: 0.9199
# Epoch 95/100
#
# Epoch 00095: val_loss improved from 0.21327 to 0.21316, saving model to models/model1.hdf5
#  - 14s - loss: 0.1482 - get_f1: 0.9523 - val_loss: 0.2132 - val_get_f1: 0.9198
# Epoch 96/100
#
# Epoch 00096: val_loss improved from 0.21316 to 0.21305, saving model to models/model1.hdf5
#  - 14s - loss: 0.1481 - get_f1: 0.9520 - val_loss: 0.2130 - val_get_f1: 0.9199
# Epoch 97/100
#
# Epoch 00097: val_loss improved from 0.21305 to 0.21300, saving model to models/model1.hdf5
#  - 14s - loss: 0.1464 - get_f1: 0.9531 - val_loss: 0.2130 - val_get_f1: 0.9209
# Epoch 98/100
#
# Epoch 00098: val_loss improved from 0.21300 to 0.21296, saving model to models/model1.hdf5
#  - 14s - loss: 0.1458 - get_f1: 0.9528 - val_loss: 0.2130 - val_get_f1: 0.9204
# Epoch 99/100
#
# Epoch 00099: val_loss improved from 0.21296 to 0.21291, saving model to models/model1.hdf5
#  - 14s - loss: 0.1446 - get_f1: 0.9529 - val_loss: 0.2129 - val_get_f1: 0.9209
# Epoch 100/100
#
# Epoch 00100: val_loss improved from 0.21291 to 0.21290, saving model to models/model1.hdf5
#  - 14s - loss: 0.1449 - get_f1: 0.9526 - val_loss: 0.2129 - val_get_f1: 0.9206

# %% [markdown]
# Model2:
# * learning_rate=1e-3,
# * epochs=100,
# * batch_size=128,
# * layers=1,
# * units=64,
# * dropout_rate=0.3.

# %%
result2 = train_model(((X_train_features,y_train), (X_valid_features, y_valid)),
                      units = 64,
                      layers=1,
                      filepath='models/model2.hdf5',
                      log_dir='logs/mlp_5_5/model2')
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dropout (Dropout)            (None, 20000)             0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 20001
# =================================================================
# Total params: 20,001
# Trainable params: 20,001
# Non-trainable params: 0
# _________________________________________________________________
# Train on 35822 samples, validate on 6322 samples
# Epoch 1/100
#
# Epoch 00001: val_loss improved from inf to 0.61410, saving model to models/model2.hdf5
#  - 15s - loss: 0.6527 - get_f1: 0.8214 - val_loss: 0.6141 - val_get_f1: 0.8592
# Epoch 2/100
#
# Epoch 00002: val_loss improved from 0.61410 to 0.55457, saving model to models/model2.hdf5
#  - 14s - loss: 0.5820 - get_f1: 0.8594 - val_loss: 0.5546 - val_get_f1: 0.8714
# Epoch 3/100
#
# Epoch 00003: val_loss improved from 0.55457 to 0.50892, saving model to models/model2.hdf5
#  - 15s - loss: 0.5293 - get_f1: 0.8662 - val_loss: 0.5089 - val_get_f1: 0.8758
# Epoch 4/100
#
# Epoch 00004: val_loss improved from 0.50892 to 0.47282, saving model to models/model2.hdf5
#  - 15s - loss: 0.4875 - get_f1: 0.8733 - val_loss: 0.4728 - val_get_f1: 0.8829
# Epoch 5/100
#
# Epoch 00005: val_loss improved from 0.47282 to 0.44360, saving model to models/model2.hdf5
#  - 14s - loss: 0.4545 - get_f1: 0.8795 - val_loss: 0.4436 - val_get_f1: 0.8860
# Epoch 6/100
#
# Epoch 00006: val_loss improved from 0.44360 to 0.41942, saving model to models/model2.hdf5
#  - 14s - loss: 0.4269 - get_f1: 0.8839 - val_loss: 0.4194 - val_get_f1: 0.8902
# Epoch 7/100
#
# Epoch 00007: val_loss improved from 0.41942 to 0.39917, saving model to models/model2.hdf5
#  - 14s - loss: 0.4045 - get_f1: 0.8876 - val_loss: 0.3992 - val_get_f1: 0.8910
# Epoch 8/100
#
# Epoch 00008: val_loss improved from 0.39917 to 0.38195, saving model to models/model2.hdf5
#  - 14s - loss: 0.3848 - get_f1: 0.8916 - val_loss: 0.3820 - val_get_f1: 0.8934
# Epoch 9/100
#
# Epoch 00009: val_loss improved from 0.38195 to 0.36710, saving model to models/model2.hdf5
#  - 14s - loss: 0.3684 - get_f1: 0.8941 - val_loss: 0.3671 - val_get_f1: 0.8941
# Epoch 10/100
#
# Epoch 00010: val_loss improved from 0.36710 to 0.35414, saving model to models/model2.hdf5
#  - 14s - loss: 0.3535 - get_f1: 0.8967 - val_loss: 0.3541 - val_get_f1: 0.8978
# Epoch 11/100
#
# Epoch 00011: val_loss improved from 0.35414 to 0.34270, saving model to models/model2.hdf5
#  - 14s - loss: 0.3405 - get_f1: 0.9003 - val_loss: 0.3427 - val_get_f1: 0.8994
# Epoch 12/100
#
# Epoch 00012: val_loss improved from 0.34270 to 0.33264, saving model to models/model2.hdf5
#  - 14s - loss: 0.3291 - get_f1: 0.9027 - val_loss: 0.3326 - val_get_f1: 0.9020
# Epoch 13/100
#
# Epoch 00013: val_loss improved from 0.33264 to 0.32363, saving model to models/model2.hdf5
#  - 14s - loss: 0.3194 - get_f1: 0.9026 - val_loss: 0.3236 - val_get_f1: 0.9022
# Epoch 14/100
#
# Epoch 00014: val_loss improved from 0.32363 to 0.31557, saving model to models/model2.hdf5
#  - 15s - loss: 0.3096 - get_f1: 0.9054 - val_loss: 0.3156 - val_get_f1: 0.9035
# Epoch 15/100
#
# Epoch 00015: val_loss improved from 0.31557 to 0.30830, saving model to models/model2.hdf5
#  - 14s - loss: 0.3009 - get_f1: 0.9088 - val_loss: 0.3083 - val_get_f1: 0.9050
# Epoch 16/100
#
# Epoch 00016: val_loss improved from 0.30830 to 0.30184, saving model to models/model2.hdf5
#  - 14s - loss: 0.2933 - get_f1: 0.9115 - val_loss: 0.3018 - val_get_f1: 0.9067
# Epoch 17/100
#
# Epoch 00017: val_loss improved from 0.30184 to 0.29590, saving model to models/model2.hdf5
#  - 14s - loss: 0.2864 - get_f1: 0.9111 - val_loss: 0.2959 - val_get_f1: 0.9063
# Epoch 18/100
#
# Epoch 00018: val_loss improved from 0.29590 to 0.29047, saving model to models/model2.hdf5
#  - 14s - loss: 0.2796 - get_f1: 0.9131 - val_loss: 0.2905 - val_get_f1: 0.9093
# Epoch 19/100
#
# Epoch 00019: val_loss improved from 0.29047 to 0.28553, saving model to models/model2.hdf5
#  - 14s - loss: 0.2741 - get_f1: 0.9141 - val_loss: 0.2855 - val_get_f1: 0.9091
# Epoch 20/100
#
# Epoch 00020: val_loss improved from 0.28553 to 0.28101, saving model to models/model2.hdf5
#  - 14s - loss: 0.2691 - get_f1: 0.9160 - val_loss: 0.2810 - val_get_f1: 0.9108
# Epoch 21/100
#
# Epoch 00021: val_loss improved from 0.28101 to 0.27688, saving model to models/model2.hdf5
#  - 14s - loss: 0.2632 - get_f1: 0.9176 - val_loss: 0.2769 - val_get_f1: 0.9105
# Epoch 22/100
#
# Epoch 00022: val_loss improved from 0.27688 to 0.27301, saving model to models/model2.hdf5
#  - 14s - loss: 0.2588 - get_f1: 0.9184 - val_loss: 0.2730 - val_get_f1: 0.9137
# Epoch 23/100
#
# Epoch 00023: val_loss improved from 0.27301 to 0.26946, saving model to models/model2.hdf5
#  - 15s - loss: 0.2527 - get_f1: 0.9213 - val_loss: 0.2695 - val_get_f1: 0.9131
# Epoch 24/100
#
# Epoch 00024: val_loss improved from 0.26946 to 0.26621, saving model to models/model2.hdf5
#  - 14s - loss: 0.2502 - get_f1: 0.9210 - val_loss: 0.2662 - val_get_f1: 0.9130
# Epoch 25/100
#
# Epoch 00025: val_loss improved from 0.26621 to 0.26321, saving model to models/model2.hdf5
#  - 14s - loss: 0.2472 - get_f1: 0.9213 - val_loss: 0.2632 - val_get_f1: 0.9156
# Epoch 26/100
#
# Epoch 00026: val_loss improved from 0.26321 to 0.26035, saving model to models/model2.hdf5
#  - 14s - loss: 0.2420 - get_f1: 0.9227 - val_loss: 0.2603 - val_get_f1: 0.9137
# Epoch 27/100
#
# Epoch 00027: val_loss improved from 0.26035 to 0.25773, saving model to models/model2.hdf5
#  - 14s - loss: 0.2395 - get_f1: 0.9222 - val_loss: 0.2577 - val_get_f1: 0.9156
# Epoch 28/100
#
# Epoch 00028: val_loss improved from 0.25773 to 0.25526, saving model to models/model2.hdf5
#  - 15s - loss: 0.2356 - get_f1: 0.9236 - val_loss: 0.2553 - val_get_f1: 0.9151
# Epoch 29/100
#
# Epoch 00029: val_loss improved from 0.25526 to 0.25296, saving model to models/model2.hdf5
#  - 14s - loss: 0.2313 - get_f1: 0.9264 - val_loss: 0.2530 - val_get_f1: 0.9170
# Epoch 30/100
#
# Epoch 00030: val_loss improved from 0.25296 to 0.25072, saving model to models/model2.hdf5
#  - 17s - loss: 0.2283 - get_f1: 0.9270 - val_loss: 0.2507 - val_get_f1: 0.9183
# Epoch 31/100
#
# Epoch 00031: val_loss improved from 0.25072 to 0.24871, saving model to models/model2.hdf5
#  - 15s - loss: 0.2257 - get_f1: 0.9278 - val_loss: 0.2487 - val_get_f1: 0.9180
# Epoch 32/100
#
# Epoch 00032: val_loss improved from 0.24871 to 0.24681, saving model to models/model2.hdf5
#  - 15s - loss: 0.2222 - get_f1: 0.9287 - val_loss: 0.2468 - val_get_f1: 0.9195
# Epoch 33/100
#
# Epoch 00033: val_loss improved from 0.24681 to 0.24504, saving model to models/model2.hdf5
#  - 15s - loss: 0.2207 - get_f1: 0.9291 - val_loss: 0.2450 - val_get_f1: 0.9162
# Epoch 34/100
#
# Epoch 00034: val_loss improved from 0.24504 to 0.24340, saving model to models/model2.hdf5
#  - 14s - loss: 0.2185 - get_f1: 0.9299 - val_loss: 0.2434 - val_get_f1: 0.9192
# Epoch 35/100
#
# Epoch 00035: val_loss improved from 0.24340 to 0.24180, saving model to models/model2.hdf5
#  - 14s - loss: 0.2154 - get_f1: 0.9308 - val_loss: 0.2418 - val_get_f1: 0.9185
# Epoch 36/100
#
# Epoch 00036: val_loss improved from 0.24180 to 0.24029, saving model to models/model2.hdf5
#  - 14s - loss: 0.2122 - get_f1: 0.9312 - val_loss: 0.2403 - val_get_f1: 0.9184
# Epoch 37/100
#
# Epoch 00037: val_loss improved from 0.24029 to 0.23891, saving model to models/model2.hdf5
#  - 15s - loss: 0.2110 - get_f1: 0.9326 - val_loss: 0.2389 - val_get_f1: 0.9185
# Epoch 38/100
#
# Epoch 00038: val_loss improved from 0.23891 to 0.23762, saving model to models/model2.hdf5
#  - 15s - loss: 0.2094 - get_f1: 0.9331 - val_loss: 0.2376 - val_get_f1: 0.9191
# Epoch 39/100
#
# Epoch 00039: val_loss improved from 0.23762 to 0.23633, saving model to models/model2.hdf5
#  - 15s - loss: 0.2068 - get_f1: 0.9335 - val_loss: 0.2363 - val_get_f1: 0.9200
# Epoch 40/100
#
# Epoch 00040: val_loss improved from 0.23633 to 0.23512, saving model to models/model2.hdf5
#  - 15s - loss: 0.2048 - get_f1: 0.9341 - val_loss: 0.2351 - val_get_f1: 0.9197
# Epoch 41/100
#
# Epoch 00041: val_loss improved from 0.23512 to 0.23401, saving model to models/model2.hdf5
#  - 15s - loss: 0.2020 - get_f1: 0.9354 - val_loss: 0.2340 - val_get_f1: 0.9193
# Epoch 42/100
#
# Epoch 00042: val_loss improved from 0.23401 to 0.23296, saving model to models/model2.hdf5
#  - 14s - loss: 0.2004 - get_f1: 0.9343 - val_loss: 0.2330 - val_get_f1: 0.9200
# Epoch 43/100
#
# Epoch 00043: val_loss improved from 0.23296 to 0.23185, saving model to models/model2.hdf5
#  - 14s - loss: 0.1984 - get_f1: 0.9350 - val_loss: 0.2318 - val_get_f1: 0.9210
# Epoch 44/100
#
# Epoch 00044: val_loss improved from 0.23185 to 0.23084, saving model to models/model2.hdf5
#  - 14s - loss: 0.1979 - get_f1: 0.9369 - val_loss: 0.2308 - val_get_f1: 0.9202
# Epoch 45/100
#
# Epoch 00045: val_loss improved from 0.23084 to 0.22997, saving model to models/model2.hdf5
#  - 14s - loss: 0.1957 - get_f1: 0.9369 - val_loss: 0.2300 - val_get_f1: 0.9197
# Epoch 46/100
#
# Epoch 00046: val_loss improved from 0.22997 to 0.22906, saving model to models/model2.hdf5
#  - 15s - loss: 0.1923 - get_f1: 0.9385 - val_loss: 0.2291 - val_get_f1: 0.9203
# Epoch 47/100
#
# Epoch 00047: val_loss improved from 0.22906 to 0.22825, saving model to models/model2.hdf5
#  - 15s - loss: 0.1912 - get_f1: 0.9382 - val_loss: 0.2283 - val_get_f1: 0.9195
# Epoch 48/100
#
# Epoch 00048: val_loss improved from 0.22825 to 0.22745, saving model to models/model2.hdf5
#  - 15s - loss: 0.1893 - get_f1: 0.9389 - val_loss: 0.2275 - val_get_f1: 0.9198
# Epoch 49/100
#
# Epoch 00049: val_loss improved from 0.22745 to 0.22669, saving model to models/model2.hdf5
#  - 14s - loss: 0.1893 - get_f1: 0.9388 - val_loss: 0.2267 - val_get_f1: 0.9206
# Epoch 50/100
#
# Epoch 00050: val_loss improved from 0.22669 to 0.22595, saving model to models/model2.hdf5
#  - 15s - loss: 0.1885 - get_f1: 0.9385 - val_loss: 0.2259 - val_get_f1: 0.9210
# Epoch 51/100
#
# Epoch 00051: val_loss improved from 0.22595 to 0.22532, saving model to models/model2.hdf5
#  - 14s - loss: 0.1871 - get_f1: 0.9396 - val_loss: 0.2253 - val_get_f1: 0.9216
# Epoch 52/100
#
# Epoch 00052: val_loss improved from 0.22532 to 0.22466, saving model to models/model2.hdf5
#  - 14s - loss: 0.1849 - get_f1: 0.9402 - val_loss: 0.2247 - val_get_f1: 0.9214
# Epoch 53/100
#
# Epoch 00053: val_loss improved from 0.22466 to 0.22410, saving model to models/model2.hdf5
#  - 15s - loss: 0.1847 - get_f1: 0.9397 - val_loss: 0.2241 - val_get_f1: 0.9199
# Epoch 54/100
#
# Epoch 00054: val_loss improved from 0.22410 to 0.22349, saving model to models/model2.hdf5
#  - 15s - loss: 0.1828 - get_f1: 0.9411 - val_loss: 0.2235 - val_get_f1: 0.9211
# Epoch 55/100
#
# Epoch 00055: val_loss improved from 0.22349 to 0.22299, saving model to models/model2.hdf5
#  - 14s - loss: 0.1825 - get_f1: 0.9390 - val_loss: 0.2230 - val_get_f1: 0.9211
# Epoch 56/100
#
# Epoch 00056: val_loss improved from 0.22299 to 0.22250, saving model to models/model2.hdf5
#  - 14s - loss: 0.1806 - get_f1: 0.9397 - val_loss: 0.2225 - val_get_f1: 0.9216
# Epoch 57/100
#
# Epoch 00057: val_loss improved from 0.22250 to 0.22197, saving model to models/model2.hdf5
#  - 14s - loss: 0.1787 - get_f1: 0.9413 - val_loss: 0.2220 - val_get_f1: 0.9206
# Epoch 58/100
#
# Epoch 00058: val_loss improved from 0.22197 to 0.22150, saving model to models/model2.hdf5
#  - 14s - loss: 0.1786 - get_f1: 0.9417 - val_loss: 0.2215 - val_get_f1: 0.9208
# Epoch 59/100
#
# Epoch 00059: val_loss improved from 0.22150 to 0.22100, saving model to models/model2.hdf5
#  - 15s - loss: 0.1763 - get_f1: 0.9432 - val_loss: 0.2210 - val_get_f1: 0.9212
# Epoch 60/100
#
# Epoch 00060: val_loss improved from 0.22100 to 0.22049, saving model to models/model2.hdf5
#  - 14s - loss: 0.1767 - get_f1: 0.9427 - val_loss: 0.2205 - val_get_f1: 0.9196
# Epoch 61/100
#
# Epoch 00061: val_loss improved from 0.22049 to 0.22008, saving model to models/model2.hdf5
#  - 14s - loss: 0.1729 - get_f1: 0.9450 - val_loss: 0.2201 - val_get_f1: 0.9214
# Epoch 62/100
#
# Epoch 00062: val_loss improved from 0.22008 to 0.21967, saving model to models/model2.hdf5
#  - 14s - loss: 0.1726 - get_f1: 0.9436 - val_loss: 0.2197 - val_get_f1: 0.9211
# Epoch 63/100
#
# Epoch 00063: val_loss improved from 0.21967 to 0.21933, saving model to models/model2.hdf5
#  - 14s - loss: 0.1723 - get_f1: 0.9453 - val_loss: 0.2193 - val_get_f1: 0.9205
# Epoch 64/100
#
# Epoch 00064: val_loss improved from 0.21933 to 0.21899, saving model to models/model2.hdf5
#  - 15s - loss: 0.1716 - get_f1: 0.9435 - val_loss: 0.2190 - val_get_f1: 0.9206
# Epoch 65/100
#
# Epoch 00065: val_loss improved from 0.21899 to 0.21871, saving model to models/model2.hdf5
#  - 14s - loss: 0.1696 - get_f1: 0.9440 - val_loss: 0.2187 - val_get_f1: 0.9210
# Epoch 66/100
#
# Epoch 00066: val_loss improved from 0.21871 to 0.21837, saving model to models/model2.hdf5
#  - 14s - loss: 0.1696 - get_f1: 0.9453 - val_loss: 0.2184 - val_get_f1: 0.9217
# Epoch 67/100
#
# Epoch 00067: val_loss improved from 0.21837 to 0.21797, saving model to models/model2.hdf5
#  - 15s - loss: 0.1666 - get_f1: 0.9464 - val_loss: 0.2180 - val_get_f1: 0.9209
# Epoch 68/100
#
# Epoch 00068: val_loss improved from 0.21797 to 0.21763, saving model to models/model2.hdf5
#  - 15s - loss: 0.1666 - get_f1: 0.9467 - val_loss: 0.2176 - val_get_f1: 0.9219
# Epoch 69/100
#
# Epoch 00069: val_loss improved from 0.21763 to 0.21735, saving model to models/model2.hdf5
#  - 15s - loss: 0.1649 - get_f1: 0.9467 - val_loss: 0.2173 - val_get_f1: 0.9203
# Epoch 70/100
#
# Epoch 00070: val_loss improved from 0.21735 to 0.21708, saving model to models/model2.hdf5
#  - 15s - loss: 0.1657 - get_f1: 0.9457 - val_loss: 0.2171 - val_get_f1: 0.9203
# Epoch 71/100
#
# Epoch 00071: val_loss improved from 0.21708 to 0.21676, saving model to models/model2.hdf5
#  - 15s - loss: 0.1649 - get_f1: 0.9456 - val_loss: 0.2168 - val_get_f1: 0.9206
# Epoch 72/100
#
# Epoch 00072: val_loss improved from 0.21676 to 0.21649, saving model to models/model2.hdf5
#  - 15s - loss: 0.1637 - get_f1: 0.9476 - val_loss: 0.2165 - val_get_f1: 0.9211
# Epoch 73/100
#
# Epoch 00073: val_loss improved from 0.21649 to 0.21618, saving model to models/model2.hdf5
#  - 15s - loss: 0.1633 - get_f1: 0.9460 - val_loss: 0.2162 - val_get_f1: 0.9214
# Epoch 74/100
#
# Epoch 00074: val_loss improved from 0.21618 to 0.21591, saving model to models/model2.hdf5
#  - 16s - loss: 0.1606 - get_f1: 0.9480 - val_loss: 0.2159 - val_get_f1: 0.9200
# Epoch 75/100
#
# Epoch 00075: val_loss improved from 0.21591 to 0.21574, saving model to models/model2.hdf5
#  - 16s - loss: 0.1627 - get_f1: 0.9467 - val_loss: 0.2157 - val_get_f1: 0.9200
# Epoch 76/100
#
# Epoch 00076: val_loss improved from 0.21574 to 0.21550, saving model to models/model2.hdf5
#  - 15s - loss: 0.1616 - get_f1: 0.9473 - val_loss: 0.2155 - val_get_f1: 0.9213
# Epoch 77/100
#
# Epoch 00077: val_loss improved from 0.21550 to 0.21531, saving model to models/model2.hdf5
#  - 15s - loss: 0.1602 - get_f1: 0.9489 - val_loss: 0.2153 - val_get_f1: 0.9207
# Epoch 78/100
#
# Epoch 00078: val_loss improved from 0.21531 to 0.21512, saving model to models/model2.hdf5
#  - 15s - loss: 0.1585 - get_f1: 0.9493 - val_loss: 0.2151 - val_get_f1: 0.9210
# Epoch 79/100
#
# Epoch 00079: val_loss improved from 0.21512 to 0.21504, saving model to models/model2.hdf5
#  - 15s - loss: 0.1577 - get_f1: 0.9495 - val_loss: 0.2150 - val_get_f1: 0.9203
# Epoch 80/100
#
# Epoch 00080: val_loss improved from 0.21504 to 0.21479, saving model to models/model2.hdf5
#  - 15s - loss: 0.1570 - get_f1: 0.9489 - val_loss: 0.2148 - val_get_f1: 0.9188
# Epoch 81/100
#
# Epoch 00081: val_loss improved from 0.21479 to 0.21470, saving model to models/model2.hdf5
#  - 15s - loss: 0.1578 - get_f1: 0.9487 - val_loss: 0.2147 - val_get_f1: 0.9202
# Epoch 82/100
#
# Epoch 00082: val_loss improved from 0.21470 to 0.21447, saving model to models/model2.hdf5
#  - 15s - loss: 0.1552 - get_f1: 0.9495 - val_loss: 0.2145 - val_get_f1: 0.9211
# Epoch 83/100
#
# Epoch 00083: val_loss improved from 0.21447 to 0.21431, saving model to models/model2.hdf5
#  - 15s - loss: 0.1550 - get_f1: 0.9495 - val_loss: 0.2143 - val_get_f1: 0.9206
# Epoch 84/100
#
# Epoch 00084: val_loss improved from 0.21431 to 0.21414, saving model to models/model2.hdf5
#  - 14s - loss: 0.1541 - get_f1: 0.9500 - val_loss: 0.2141 - val_get_f1: 0.9203
# Epoch 85/100
#
# Epoch 00085: val_loss improved from 0.21414 to 0.21406, saving model to models/model2.hdf5
#  - 14s - loss: 0.1529 - get_f1: 0.9504 - val_loss: 0.2141 - val_get_f1: 0.9197
# Epoch 86/100
#
# Epoch 00086: val_loss improved from 0.21406 to 0.21387, saving model to models/model2.hdf5
#  - 15s - loss: 0.1531 - get_f1: 0.9498 - val_loss: 0.2139 - val_get_f1: 0.9208
# Epoch 87/100
#
# Epoch 00087: val_loss improved from 0.21387 to 0.21381, saving model to models/model2.hdf5
#  - 14s - loss: 0.1538 - get_f1: 0.9492 - val_loss: 0.2138 - val_get_f1: 0.9204
# Epoch 88/100
#
# Epoch 00088: val_loss improved from 0.21381 to 0.21367, saving model to models/model2.hdf5
#  - 14s - loss: 0.1519 - get_f1: 0.9501 - val_loss: 0.2137 - val_get_f1: 0.9194
# Epoch 89/100
#
# Epoch 00089: val_loss improved from 0.21367 to 0.21360, saving model to models/model2.hdf5
#  - 14s - loss: 0.1526 - get_f1: 0.9502 - val_loss: 0.2136 - val_get_f1: 0.9198
# Epoch 90/100
#
# Epoch 00090: val_loss improved from 0.21360 to 0.21349, saving model to models/model2.hdf5
#  - 14s - loss: 0.1518 - get_f1: 0.9512 - val_loss: 0.2135 - val_get_f1: 0.9211
# Epoch 91/100
#
# Epoch 00091: val_loss improved from 0.21349 to 0.21341, saving model to models/model2.hdf5
#  - 15s - loss: 0.1488 - get_f1: 0.9528 - val_loss: 0.2134 - val_get_f1: 0.9200
# Epoch 92/100
#
# Epoch 00092: val_loss improved from 0.21341 to 0.21336, saving model to models/model2.hdf5
#  - 14s - loss: 0.1481 - get_f1: 0.9515 - val_loss: 0.2134 - val_get_f1: 0.9203
# Epoch 93/100
#
# Epoch 00093: val_loss improved from 0.21336 to 0.21325, saving model to models/model2.hdf5
#  - 15s - loss: 0.1491 - get_f1: 0.9512 - val_loss: 0.2132 - val_get_f1: 0.9199
# Epoch 94/100
#
# Epoch 00094: val_loss improved from 0.21325 to 0.21322, saving model to models/model2.hdf5
#  - 14s - loss: 0.1480 - get_f1: 0.9531 - val_loss: 0.2132 - val_get_f1: 0.9204
# Epoch 95/100
#
# Epoch 00095: val_loss improved from 0.21322 to 0.21320, saving model to models/model2.hdf5
#  - 15s - loss: 0.1485 - get_f1: 0.9517 - val_loss: 0.2132 - val_get_f1: 0.9193
# Epoch 96/100
#
# Epoch 00096: val_loss improved from 0.21320 to 0.21314, saving model to models/model2.hdf5
#  - 14s - loss: 0.1463 - get_f1: 0.9522 - val_loss: 0.2131 - val_get_f1: 0.9195
# Epoch 97/100
#
# Epoch 00097: val_loss improved from 0.21314 to 0.21312, saving model to models/model2.hdf5
#  - 14s - loss: 0.1482 - get_f1: 0.9519 - val_loss: 0.2131 - val_get_f1: 0.9185
# Epoch 98/100
#
# Epoch 00098: val_loss improved from 0.21312 to 0.21307, saving model to models/model2.hdf5
#  - 14s - loss: 0.1445 - get_f1: 0.9536 - val_loss: 0.2131 - val_get_f1: 0.9191
# Epoch 99/100
#
# Epoch 00099: val_loss improved from 0.21307 to 0.21294, saving model to models/model2.hdf5
#  - 14s - loss: 0.1446 - get_f1: 0.9530 - val_loss: 0.2129 - val_get_f1: 0.9197
# Epoch 100/100
#
# Epoch 00100: val_loss improved from 0.21294 to 0.21291, saving model to models/model2.hdf5
#  - 15s - loss: 0.1451 - get_f1: 0.9522 - val_loss: 0.2129 - val_get_f1: 0.9190

# %% [markdown]
# Model3:
# * learning_rate=5e-3,
# * epochs=100,
# * batch_size=128,
# * layers=1,
# * units=32,
# * dropout_rate=0.3.

# %%
result3 = train_model(((X_train_features,y_train), (X_valid_features, y_valid)),
                      learning_rate=5e-3,
                      units = 32,
                      layers=1,
                      filepath='models/model3.hdf5',
                      log_dir='logs/mlp_5_5/model3')
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dropout (Dropout)            (None, 20000)             0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 20001
# =================================================================
# Total params: 20,001
# Trainable params: 20,001
# Non-trainable params: 0
# _________________________________________________________________
# Train on 35822 samples, validate on 6322 samples
# Epoch 1/100
#
# Epoch 00001: val_loss improved from inf to 0.44230, saving model to models/model3.hdf5
#  - 15s - loss: 0.5469 - get_f1: 0.8411 - val_loss: 0.4423 - val_get_f1: 0.8835
# Epoch 2/100
#
# Epoch 00002: val_loss improved from 0.44230 to 0.35710, saving model to models/model3.hdf5
#  - 14s - loss: 0.3937 - get_f1: 0.8852 - val_loss: 0.3571 - val_get_f1: 0.8965
# Epoch 3/100
#
# Epoch 00003: val_loss improved from 0.35710 to 0.31404, saving model to models/model3.hdf5
#  - 15s - loss: 0.3290 - get_f1: 0.9002 - val_loss: 0.3140 - val_get_f1: 0.9049
# Epoch 4/100
#
# Epoch 00004: val_loss improved from 0.31404 to 0.28790, saving model to models/model3.hdf5
#  - 14s - loss: 0.2913 - get_f1: 0.9087 - val_loss: 0.2879 - val_get_f1: 0.9106
# Epoch 5/100
#
# Epoch 00005: val_loss improved from 0.28790 to 0.27051, saving model to models/model3.hdf5
#  - 15s - loss: 0.2665 - get_f1: 0.9156 - val_loss: 0.2705 - val_get_f1: 0.9151
# Epoch 6/100
#
# Epoch 00006: val_loss improved from 0.27051 to 0.25793, saving model to models/model3.hdf5
#  - 14s - loss: 0.2476 - get_f1: 0.9212 - val_loss: 0.2579 - val_get_f1: 0.9161
# Epoch 7/100
#
# Epoch 00007: val_loss improved from 0.25793 to 0.24886, saving model to models/model3.hdf5
#  - 14s - loss: 0.2326 - get_f1: 0.9236 - val_loss: 0.2489 - val_get_f1: 0.9151
# Epoch 8/100
#
# Epoch 00008: val_loss improved from 0.24886 to 0.24221, saving model to models/model3.hdf5
#  - 14s - loss: 0.2203 - get_f1: 0.9271 - val_loss: 0.2422 - val_get_f1: 0.9171
# Epoch 9/100
#
# Epoch 00009: val_loss improved from 0.24221 to 0.23675, saving model to models/model3.hdf5
#  - 14s - loss: 0.2111 - get_f1: 0.9295 - val_loss: 0.2368 - val_get_f1: 0.9178
# Epoch 10/100
#
# Epoch 00010: val_loss improved from 0.23675 to 0.23289, saving model to models/model3.hdf5
#  - 14s - loss: 0.2012 - get_f1: 0.9340 - val_loss: 0.2329 - val_get_f1: 0.9181
# Epoch 11/100
#
# Epoch 00011: val_loss improved from 0.23289 to 0.22848, saving model to models/model3.hdf5
#  - 14s - loss: 0.1944 - get_f1: 0.9354 - val_loss: 0.2285 - val_get_f1: 0.9188
# Epoch 12/100
#
# Epoch 00012: val_loss improved from 0.22848 to 0.22533, saving model to models/model3.hdf5
#  - 15s - loss: 0.1880 - get_f1: 0.9388 - val_loss: 0.2253 - val_get_f1: 0.9180
# Epoch 13/100
#
# Epoch 00013: val_loss improved from 0.22533 to 0.22270, saving model to models/model3.hdf5
#  - 14s - loss: 0.1826 - get_f1: 0.9394 - val_loss: 0.2227 - val_get_f1: 0.9199
# Epoch 14/100
#
# Epoch 00014: val_loss improved from 0.22270 to 0.22120, saving model to models/model3.hdf5
#  - 14s - loss: 0.1773 - get_f1: 0.9428 - val_loss: 0.2212 - val_get_f1: 0.9178
# Epoch 15/100
#
# Epoch 00015: val_loss improved from 0.22120 to 0.21950, saving model to models/model3.hdf5
#  - 14s - loss: 0.1721 - get_f1: 0.9420 - val_loss: 0.2195 - val_get_f1: 0.9173
# Epoch 16/100
#
# Epoch 00016: val_loss improved from 0.21950 to 0.21796, saving model to models/model3.hdf5
#  - 14s - loss: 0.1677 - get_f1: 0.9444 - val_loss: 0.2180 - val_get_f1: 0.9196
# Epoch 17/100
#
# Epoch 00017: val_loss improved from 0.21796 to 0.21712, saving model to models/model3.hdf5
#  - 14s - loss: 0.1638 - get_f1: 0.9459 - val_loss: 0.2171 - val_get_f1: 0.9202
# Epoch 18/100
#
# Epoch 00018: val_loss improved from 0.21712 to 0.21647, saving model to models/model3.hdf5
#  - 14s - loss: 0.1594 - get_f1: 0.9474 - val_loss: 0.2165 - val_get_f1: 0.9191
# Epoch 19/100
#
# Epoch 00019: val_loss improved from 0.21647 to 0.21593, saving model to models/model3.hdf5
#  - 15s - loss: 0.1580 - get_f1: 0.9483 - val_loss: 0.2159 - val_get_f1: 0.9188
# Epoch 20/100
#
# Epoch 00020: val_loss improved from 0.21593 to 0.21542, saving model to models/model3.hdf5
#  - 14s - loss: 0.1521 - get_f1: 0.9515 - val_loss: 0.2154 - val_get_f1: 0.9178
# Epoch 21/100
#
# Epoch 00021: val_loss improved from 0.21542 to 0.21500, saving model to models/model3.hdf5
#  - 15s - loss: 0.1519 - get_f1: 0.9492 - val_loss: 0.2150 - val_get_f1: 0.9196
# Epoch 22/100
#
# Epoch 00022: val_loss improved from 0.21500 to 0.21479, saving model to models/model3.hdf5
#  - 15s - loss: 0.1473 - get_f1: 0.9517 - val_loss: 0.2148 - val_get_f1: 0.9188
# Epoch 23/100
#
# Epoch 00023: val_loss improved from 0.21479 to 0.21446, saving model to models/model3.hdf5
#  - 14s - loss: 0.1425 - get_f1: 0.9542 - val_loss: 0.2145 - val_get_f1: 0.9197
# Epoch 24/100
#
# Epoch 00024: val_loss did not improve from 0.21446
#  - 14s - loss: 0.1432 - get_f1: 0.9535 - val_loss: 0.2145 - val_get_f1: 0.9188
# Epoch 25/100
#
# Epoch 00025: val_loss did not improve from 0.21446
#  - 14s - loss: 0.1420 - get_f1: 0.9511 - val_loss: 0.2146 - val_get_f1: 0.9176
# Epoch 26/100
#
# Epoch 00026: val_loss did not improve from 0.21446
#  - 15s - loss: 0.1394 - get_f1: 0.9533 - val_loss: 0.2147 - val_get_f1: 0.9185

# %% [markdown]
# Model4:
# * learning_rate=1e-2,
# * epochs=100,
# * batch_size=128,
# * layers=1,
# * units=32,
# * dropout_rate=0.3.

# %%
result4 = train_model(((X_train_features,y_train), (X_valid_features, y_valid)),
                      learning_rate=1e-2,
                      units = 32,
                      layers=1,
                      filepath='models/model4.hdf5',
                      log_dir='logs/mlp_5_5/model4')
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dropout (Dropout)            (None, 20000)             0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 20001
# =================================================================
# Total params: 20,001
# Trainable params: 20,001
# Non-trainable params: 0
# _________________________________________________________________
# Train on 35822 samples, validate on 6322 samples
# Epoch 1/100
#
# Epoch 00001: val_loss improved from inf to 0.35482, saving model to models/model4.hdf5
#  - 14s - loss: 0.4753 - get_f1: 0.8335 - val_loss: 0.3548 - val_get_f1: 0.8968
# Epoch 2/100
#
# Epoch 00002: val_loss improved from 0.35482 to 0.28818, saving model to models/model4.hdf5
#  - 14s - loss: 0.3142 - get_f1: 0.8998 - val_loss: 0.2882 - val_get_f1: 0.9102
# Epoch 3/100
#
# Epoch 00003: val_loss improved from 0.28818 to 0.25876, saving model to models/model4.hdf5
#  - 14s - loss: 0.2620 - get_f1: 0.9141 - val_loss: 0.2588 - val_get_f1: 0.9158
# Epoch 4/100
#
# Epoch 00004: val_loss improved from 0.25876 to 0.24265, saving model to models/model4.hdf5
#  - 15s - loss: 0.2323 - get_f1: 0.9217 - val_loss: 0.2426 - val_get_f1: 0.9170
# Epoch 5/100
#
# Epoch 00005: val_loss improved from 0.24265 to 0.23263, saving model to models/model4.hdf5
#  - 14s - loss: 0.2108 - get_f1: 0.9295 - val_loss: 0.2326 - val_get_f1: 0.9190
# Epoch 6/100
#
# Epoch 00006: val_loss improved from 0.23263 to 0.22645, saving model to models/model4.hdf5
#  - 14s - loss: 0.1989 - get_f1: 0.9329 - val_loss: 0.2265 - val_get_f1: 0.9182
# Epoch 7/100
#
# Epoch 00007: val_loss improved from 0.22645 to 0.22199, saving model to models/model4.hdf5
#  - 14s - loss: 0.1859 - get_f1: 0.9364 - val_loss: 0.2220 - val_get_f1: 0.9184
# Epoch 8/100
#
# Epoch 00008: val_loss improved from 0.22199 to 0.21929, saving model to models/model4.hdf5
#  - 14s - loss: 0.1781 - get_f1: 0.9399 - val_loss: 0.2193 - val_get_f1: 0.9209
# Epoch 9/100
#
# Epoch 00009: val_loss improved from 0.21929 to 0.21718, saving model to models/model4.hdf5
#  - 15s - loss: 0.1688 - get_f1: 0.9426 - val_loss: 0.2172 - val_get_f1: 0.9194
# Epoch 10/100
#
# Epoch 00010: val_loss improved from 0.21718 to 0.21619, saving model to models/model4.hdf5
#  - 14s - loss: 0.1615 - get_f1: 0.9460 - val_loss: 0.2162 - val_get_f1: 0.9184
# Epoch 11/100
#
# Epoch 00011: val_loss improved from 0.21619 to 0.21529, saving model to models/model4.hdf5
#  - 14s - loss: 0.1558 - get_f1: 0.9475 - val_loss: 0.2153 - val_get_f1: 0.9171
# Epoch 12/100
#
# Epoch 00012: val_loss did not improve from 0.21529
#  - 14s - loss: 0.1506 - get_f1: 0.9487 - val_loss: 0.2155 - val_get_f1: 0.9185
# Epoch 13/100
#
# Epoch 00013: val_loss did not improve from 0.21529
#  - 15s - loss: 0.1456 - get_f1: 0.9515 - val_loss: 0.2157 - val_get_f1: 0.9161
# Epoch 14/100
#
# Epoch 00014: val_loss did not improve from 0.21529
#  - 14s - loss: 0.1415 - get_f1: 0.9529 - val_loss: 0.2159 - val_get_f1: 0.9164

# %% [markdown]
# Model5:
# * learning_rate=5e-3,
# * epochs=100,
# * batch_size=128,
# * layers=1,
# * units=64,
# * dropout_rate=0.3.

# %%
result5 = train_model(((X_train_features,y_train), (X_valid_features, y_valid)),
                      learning_rate=5e-3,
                      units = 64,
                      layers=1,
                      filepath='models/model5.hdf5',
                      log_dir='logs/mlp_5_5/model5')
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dropout (Dropout)            (None, 20000)             0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 20001
# =================================================================
# Total params: 20,001
# Trainable params: 20,001
# Non-trainable params: 0
# _________________________________________________________________
# Train on 35822 samples, validate on 6322 samples
# Epoch 1/100
#
# Epoch 00001: val_loss improved from inf to 0.44277, saving model to models/model5.hdf5
#  - 15s - loss: 0.5468 - get_f1: 0.8407 - val_loss: 0.4428 - val_get_f1: 0.8834
# Epoch 2/100
#
# Epoch 00002: val_loss improved from 0.44277 to 0.35755, saving model to models/model5.hdf5
#  - 14s - loss: 0.3944 - get_f1: 0.8841 - val_loss: 0.3576 - val_get_f1: 0.8965
# Epoch 3/100
#
# Epoch 00003: val_loss improved from 0.35755 to 0.31447, saving model to models/model5.hdf5
#  - 14s - loss: 0.3300 - get_f1: 0.8976 - val_loss: 0.3145 - val_get_f1: 0.9040
# Epoch 4/100
#
# Epoch 00004: val_loss improved from 0.31447 to 0.28855, saving model to models/model5.hdf5
#  - 14s - loss: 0.2918 - get_f1: 0.9074 - val_loss: 0.2886 - val_get_f1: 0.9094
# Epoch 5/100
#
# Epoch 00005: val_loss improved from 0.28855 to 0.27108, saving model to models/model5.hdf5
#  - 14s - loss: 0.2657 - get_f1: 0.9148 - val_loss: 0.2711 - val_get_f1: 0.9133
# Epoch 6/100
#
# Epoch 00006: val_loss improved from 0.27108 to 0.25827, saving model to models/model5.hdf5
#  - 14s - loss: 0.2489 - get_f1: 0.9200 - val_loss: 0.2583 - val_get_f1: 0.9156
# Epoch 7/100
#
# Epoch 00007: val_loss improved from 0.25827 to 0.24895, saving model to models/model5.hdf5
#  - 14s - loss: 0.2327 - get_f1: 0.9244 - val_loss: 0.2489 - val_get_f1: 0.9182
# Epoch 8/100
#
# Epoch 00008: val_loss improved from 0.24895 to 0.24170, saving model to models/model5.hdf5
#  - 14s - loss: 0.2224 - get_f1: 0.9261 - val_loss: 0.2417 - val_get_f1: 0.9172
# Epoch 9/100
#
# Epoch 00009: val_loss improved from 0.24170 to 0.23603, saving model to models/model5.hdf5
#  - 15s - loss: 0.2112 - get_f1: 0.9312 - val_loss: 0.2360 - val_get_f1: 0.9189
# Epoch 10/100
#
# Epoch 00010: val_loss improved from 0.23603 to 0.23153, saving model to models/model5.hdf5
#  - 14s - loss: 0.2021 - get_f1: 0.9329 - val_loss: 0.2315 - val_get_f1: 0.9201
# Epoch 11/100
#
# Epoch 00011: val_loss improved from 0.23153 to 0.22770, saving model to models/model5.hdf5
#  - 14s - loss: 0.1953 - get_f1: 0.9362 - val_loss: 0.2277 - val_get_f1: 0.9189
# Epoch 12/100
#
# Epoch 00012: val_loss improved from 0.22770 to 0.22457, saving model to models/model5.hdf5
#  - 14s - loss: 0.1877 - get_f1: 0.9376 - val_loss: 0.2246 - val_get_f1: 0.9204
# Epoch 13/100
#
# Epoch 00013: val_loss improved from 0.22457 to 0.22225, saving model to models/model5.hdf5
#  - 15s - loss: 0.1819 - get_f1: 0.9404 - val_loss: 0.2222 - val_get_f1: 0.9220
# Epoch 14/100
#
# Epoch 00014: val_loss improved from 0.22225 to 0.22039, saving model to models/model5.hdf5
#  - 14s - loss: 0.1770 - get_f1: 0.9410 - val_loss: 0.2204 - val_get_f1: 0.9215
# Epoch 15/100
#
# Epoch 00015: val_loss improved from 0.22039 to 0.21882, saving model to models/model5.hdf5
#  - 14s - loss: 0.1721 - get_f1: 0.9435 - val_loss: 0.2188 - val_get_f1: 0.9208
# Epoch 16/100
#
# Epoch 00016: val_loss improved from 0.21882 to 0.21748, saving model to models/model5.hdf5
#  - 14s - loss: 0.1677 - get_f1: 0.9457 - val_loss: 0.2175 - val_get_f1: 0.9221
# Epoch 17/100
#
# Epoch 00017: val_loss improved from 0.21748 to 0.21649, saving model to models/model5.hdf5
#  - 14s - loss: 0.1641 - get_f1: 0.9466 - val_loss: 0.2165 - val_get_f1: 0.9188
# Epoch 18/100
#
# Epoch 00018: val_loss improved from 0.21649 to 0.21563, saving model to models/model5.hdf5
#  - 14s - loss: 0.1615 - get_f1: 0.9468 - val_loss: 0.2156 - val_get_f1: 0.9200
# Epoch 19/100
#
# Epoch 00019: val_loss improved from 0.21563 to 0.21485, saving model to models/model5.hdf5
#  - 14s - loss: 0.1569 - get_f1: 0.9477 - val_loss: 0.2148 - val_get_f1: 0.9200
# Epoch 20/100
#
# Epoch 00020: val_loss did not improve from 0.21485
#  - 14s - loss: 0.1536 - get_f1: 0.9490 - val_loss: 0.2151 - val_get_f1: 0.9179
# Epoch 21/100
#
# Epoch 00021: val_loss improved from 0.21485 to 0.21472, saving model to models/model5.hdf5
#  - 14s - loss: 0.1506 - get_f1: 0.9505 - val_loss: 0.2147 - val_get_f1: 0.9187
# Epoch 22/100
#
# Epoch 00022: val_loss improved from 0.21472 to 0.21395, saving model to models/model5.hdf5
#  - 15s - loss: 0.1481 - get_f1: 0.9516 - val_loss: 0.2140 - val_get_f1: 0.9190
# Epoch 23/100
#
# Epoch 00023: val_loss improved from 0.21395 to 0.21378, saving model to models/model5.hdf5
#  - 14s - loss: 0.1441 - get_f1: 0.9531 - val_loss: 0.2138 - val_get_f1: 0.9192
# Epoch 24/100
#
# Epoch 00024: val_loss did not improve from 0.21378
#  - 15s - loss: 0.1418 - get_f1: 0.9536 - val_loss: 0.2138 - val_get_f1: 0.9205
# Epoch 25/100
#
# Epoch 00025: val_loss did not improve from 0.21378
#  - 14s - loss: 0.1433 - get_f1: 0.9511 - val_loss: 0.2138 - val_get_f1: 0.9195
# Epoch 26/100
#
# Epoch 00026: val_loss improved from 0.21378 to 0.21367, saving model to models/model5.hdf5
#  - 15s - loss: 0.1391 - get_f1: 0.9539 - val_loss: 0.2137 - val_get_f1: 0.9192
# Epoch 27/100
#
# Epoch 00027: val_loss did not improve from 0.21367
#  - 15s - loss: 0.1363 - get_f1: 0.9554 - val_loss: 0.2142 - val_get_f1: 0.9197
# Epoch 28/100
#
# Epoch 00028: val_loss did not improve from 0.21367
#  - 14s - loss: 0.1337 - get_f1: 0.9557 - val_loss: 0.2146 - val_get_f1: 0.9184
# Epoch 29/100
#
# Epoch 00029: val_loss did not improve from 0.21367
#  - 14s - loss: 0.1331 - get_f1: 0.9556 - val_loss: 0.2146 - val_get_f1: 0.9191

# %% [markdown]
# Model6:
# * learning_rate=5e-3,
# * epochs=1000,
# * batch_size=128,
# * layers=2,
# * units=64,
# * dropout_rate=0.3.

# %%
result6 = train_model(((X_train_features,y_train), (X_valid_features, y_valid)),
                      learning_rate=5e-3,
                      units = 64,
                      layers=2,
                      filepath='models/model6.hdf5',
                      log_dir='logs/mlp_5_5/model6')
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dropout (Dropout)            (None, 20000)             0
# _________________________________________________________________
# dense (Dense)                (None, 64)                1280064
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 1,280,129
# Trainable params: 1,280,129
# Non-trainable params: 0
# _________________________________________________________________
# Train on 35822 samples, validate on 6322 samples
# Epoch 1/100
#
# Epoch 00001: val_loss improved from inf to 0.22292, saving model to models/model6.hdf5
#  - 20s - loss: 0.3259 - get_f1: 0.8557 - val_loss: 0.2229 - val_get_f1: 0.9122
# Epoch 2/100
#
# Epoch 00002: val_loss improved from 0.22292 to 0.22188, saving model to models/model6.hdf5
#  - 20s - loss: 0.1921 - get_f1: 0.9238 - val_loss: 0.2219 - val_get_f1: 0.9147
# Epoch 3/100
#
# Epoch 00003: val_loss did not improve from 0.22188
#  - 20s - loss: 0.1540 - get_f1: 0.9378 - val_loss: 0.2316 - val_get_f1: 0.9116
# Epoch 4/100
#
# Epoch 00004: val_loss did not improve from 0.22188
#  - 20s - loss: 0.1287 - get_f1: 0.9479 - val_loss: 0.2453 - val_get_f1: 0.9098
# Epoch 5/100
#
# Epoch 00005: val_loss did not improve from 0.22188
#  - 20s - loss: 0.1065 - get_f1: 0.9588 - val_loss: 0.2621 - val_get_f1: 0.9111

# %% [markdown]
# Model7:
# * learning_rate=5e-3,
# * epochs=100,
# * batch_size=128,
# * layers=2,
# * units=64,
# * dropout_rate=0.6.

# %%
result7 = train_model(((X_train_features,y_train), (X_valid_features, y_valid)),
                      learning_rate=5e-3,
                      units = 64,
                      layers=2,
                      dropout_rate=0.6,
                      filepath='models/model7.hdf5',
                      log_dir='logs/mlp_5_5/model7')
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dropout (Dropout)            (None, 20000)             0
# _________________________________________________________________
# dense (Dense)                (None, 64)                1280064
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 1,280,129
# Trainable params: 1,280,129
# Non-trainable params: 0
# _________________________________________________________________
# Train on 35822 samples, validate on 6322 samples
# Epoch 1/100
#
# Epoch 00001: val_loss improved from inf to 0.25987, saving model to models/model7.hdf5
#  - 20s - loss: 0.4104 - get_f1: 0.8184 - val_loss: 0.2599 - val_get_f1: 0.9007
# Epoch 2/100
#
# Epoch 00002: val_loss improved from 0.25987 to 0.24723, saving model to models/model7.hdf5
#  - 20s - loss: 0.3098 - get_f1: 0.8675 - val_loss: 0.2472 - val_get_f1: 0.9083
# Epoch 3/100
#
# Epoch 00003: val_loss improved from 0.24723 to 0.23183, saving model to models/model7.hdf5
#  - 20s - loss: 0.2828 - get_f1: 0.8791 - val_loss: 0.2318 - val_get_f1: 0.9118
# Epoch 4/100
#
# Epoch 00004: val_loss improved from 0.23183 to 0.22629, saving model to models/model7.hdf5
#  - 20s - loss: 0.2728 - get_f1: 0.8854 - val_loss: 0.2263 - val_get_f1: 0.9147
# Epoch 5/100
#
# Epoch 00005: val_loss improved from 0.22629 to 0.22230, saving model to models/model7.hdf5
#  - 20s - loss: 0.2600 - get_f1: 0.8912 - val_loss: 0.2223 - val_get_f1: 0.9152
# Epoch 6/100
#
# Epoch 00006: val_loss did not improve from 0.22230
#  - 19s - loss: 0.2561 - get_f1: 0.8927 - val_loss: 0.2226 - val_get_f1: 0.9193
# Epoch 7/100
#
# Epoch 00007: val_loss did not improve from 0.22230
#  - 20s - loss: 0.2479 - get_f1: 0.8977 - val_loss: 0.2243 - val_get_f1: 0.9149
# Epoch 8/100
#
# Epoch 00008: val_loss improved from 0.22230 to 0.21914, saving model to models/model7.hdf5
#  - 20s - loss: 0.2386 - get_f1: 0.8992 - val_loss: 0.2191 - val_get_f1: 0.9161
# Epoch 9/100
#
# Epoch 00009: val_loss did not improve from 0.21914
#  - 20s - loss: 0.2311 - get_f1: 0.9035 - val_loss: 0.2236 - val_get_f1: 0.9142
# Epoch 10/100
#
# Epoch 00010: val_loss did not improve from 0.21914
#  - 20s - loss: 0.2299 - get_f1: 0.9024 - val_loss: 0.2255 - val_get_f1: 0.9156
# Epoch 11/100
#
# Epoch 00011: val_loss did not improve from 0.21914
#  - 20s - loss: 0.2296 - get_f1: 0.9058 - val_loss: 0.2274 - val_get_f1: 0.9128

# %% [markdown]
# Model8:
# * learning_rate=1e-3,
# * epochs=100,
# * batch_size=128,
# * layers=1,
# * units=32,
# * dropout_rate=0.1.

# %%
result8 = train_model(((X_train_features,y_train), (X_valid_features, y_valid)),
                    filepath='models/model8.hdf5',
                      layers=1,
                      dropout_rate=0.1,
                      units=32,
                      learning_rate=1e-3,
                     log_dir='logs/mlp_5_5/model8')
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dropout (Dropout)            (None, 20000)             0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 20001
# =================================================================
# Total params: 20,001
# Trainable params: 20,001
# Non-trainable params: 0
# _________________________________________________________________
# Train on 35822 samples, validate on 6322 samples
# Epoch 1/100
#
# Epoch 00001: val_loss improved from inf to 0.60705, saving model to models/model8.hdf5
#  - 15s - loss: 0.6489 - get_f1: 0.8203 - val_loss: 0.6070 - val_get_f1: 0.8616
# Epoch 2/100
#
# Epoch 00002: val_loss improved from 0.60705 to 0.54405, saving model to models/model8.hdf5
#  - 15s - loss: 0.5729 - get_f1: 0.8635 - val_loss: 0.5440 - val_get_f1: 0.8702
# Epoch 3/100
#
# Epoch 00003: val_loss improved from 0.54405 to 0.49639, saving model to models/model8.hdf5
#  - 14s - loss: 0.5161 - get_f1: 0.8747 - val_loss: 0.4964 - val_get_f1: 0.8760
# Epoch 4/100
#
# Epoch 00004: val_loss improved from 0.49639 to 0.45921, saving model to models/model8.hdf5
#  - 14s - loss: 0.4724 - get_f1: 0.8808 - val_loss: 0.4592 - val_get_f1: 0.8825
# Epoch 5/100
#
# Epoch 00005: val_loss improved from 0.45921 to 0.42952, saving model to models/model8.hdf5
#  - 14s - loss: 0.4376 - get_f1: 0.8872 - val_loss: 0.4295 - val_get_f1: 0.8876
# Epoch 6/100
#
# Epoch 00006: val_loss improved from 0.42952 to 0.40528, saving model to models/model8.hdf5
#  - 14s - loss: 0.4090 - get_f1: 0.8921 - val_loss: 0.4053 - val_get_f1: 0.8916
# Epoch 7/100
#
# Epoch 00007: val_loss improved from 0.40528 to 0.38502, saving model to models/model8.hdf5
#  - 14s - loss: 0.3853 - get_f1: 0.8956 - val_loss: 0.3850 - val_get_f1: 0.8924
# Epoch 8/100
#
# Epoch 00008: val_loss improved from 0.38502 to 0.36787, saving model to models/model8.hdf5
#  - 14s - loss: 0.3658 - get_f1: 0.9005 - val_loss: 0.3679 - val_get_f1: 0.8940
# Epoch 9/100
#
# Epoch 00009: val_loss improved from 0.36787 to 0.35331, saving model to models/model8.hdf5
#  - 14s - loss: 0.3484 - get_f1: 0.9035 - val_loss: 0.3533 - val_get_f1: 0.8940
# Epoch 10/100
#
# Epoch 00010: val_loss improved from 0.35331 to 0.34054, saving model to models/model8.hdf5
#  - 15s - loss: 0.3333 - get_f1: 0.9064 - val_loss: 0.3405 - val_get_f1: 0.8986
# Epoch 11/100
#
# Epoch 00011: val_loss improved from 0.34054 to 0.32947, saving model to models/model8.hdf5
#  - 14s - loss: 0.3203 - get_f1: 0.9101 - val_loss: 0.3295 - val_get_f1: 0.9018
# Epoch 12/100
#
# Epoch 00012: val_loss improved from 0.32947 to 0.31974, saving model to models/model8.hdf5
#  - 14s - loss: 0.3089 - get_f1: 0.9121 - val_loss: 0.3197 - val_get_f1: 0.9013
# Epoch 13/100
#
# Epoch 00013: val_loss improved from 0.31974 to 0.31105, saving model to models/model8.hdf5
#  - 14s - loss: 0.2981 - get_f1: 0.9143 - val_loss: 0.3111 - val_get_f1: 0.9045
# Epoch 14/100
#
# Epoch 00014: val_loss improved from 0.31105 to 0.30334, saving model to models/model8.hdf5
#  - 14s - loss: 0.2886 - get_f1: 0.9154 - val_loss: 0.3033 - val_get_f1: 0.9058
# Epoch 15/100
#
# Epoch 00015: val_loss improved from 0.30334 to 0.29636, saving model to models/model8.hdf5
#  - 14s - loss: 0.2796 - get_f1: 0.9194 - val_loss: 0.2964 - val_get_f1: 0.9072
# Epoch 16/100
#
# Epoch 00016: val_loss improved from 0.29636 to 0.29009, saving model to models/model8.hdf5
#  - 14s - loss: 0.2722 - get_f1: 0.9213 - val_loss: 0.2901 - val_get_f1: 0.9090
# Epoch 17/100
#
# Epoch 00017: val_loss improved from 0.29009 to 0.28440, saving model to models/model8.hdf5
#  - 14s - loss: 0.2644 - get_f1: 0.9221 - val_loss: 0.2844 - val_get_f1: 0.9097
# Epoch 18/100
#
# Epoch 00018: val_loss improved from 0.28440 to 0.27926, saving model to models/model8.hdf5
#  - 14s - loss: 0.2578 - get_f1: 0.9236 - val_loss: 0.2793 - val_get_f1: 0.9105
# Epoch 19/100
#
# Epoch 00019: val_loss improved from 0.27926 to 0.27452, saving model to models/model8.hdf5
#  - 14s - loss: 0.2520 - get_f1: 0.9264 - val_loss: 0.2745 - val_get_f1: 0.9110
# Epoch 20/100
#
# Epoch 00020: val_loss improved from 0.27452 to 0.27023, saving model to models/model8.hdf5
#  - 14s - loss: 0.2457 - get_f1: 0.9277 - val_loss: 0.2702 - val_get_f1: 0.9113
# Epoch 21/100
#
# Epoch 00021: val_loss improved from 0.27023 to 0.26632, saving model to models/model8.hdf5
#  - 14s - loss: 0.2410 - get_f1: 0.9275 - val_loss: 0.2663 - val_get_f1: 0.9118
# Epoch 22/100
#
# Epoch 00022: val_loss improved from 0.26632 to 0.26267, saving model to models/model8.hdf5
#  - 14s - loss: 0.2356 - get_f1: 0.9306 - val_loss: 0.2627 - val_get_f1: 0.9141
# Epoch 23/100
#
# Epoch 00023: val_loss improved from 0.26267 to 0.25935, saving model to models/model8.hdf5
#  - 14s - loss: 0.2312 - get_f1: 0.9309 - val_loss: 0.2594 - val_get_f1: 0.9147
# Epoch 24/100
#
# Epoch 00024: val_loss improved from 0.25935 to 0.25632, saving model to models/model8.hdf5
#  - 15s - loss: 0.2264 - get_f1: 0.9316 - val_loss: 0.2563 - val_get_f1: 0.9166
# Epoch 25/100
#
# Epoch 00025: val_loss improved from 0.25632 to 0.25352, saving model to models/model8.hdf5
#  - 15s - loss: 0.2221 - get_f1: 0.9339 - val_loss: 0.2535 - val_get_f1: 0.9164
# Epoch 26/100
#
# Epoch 00026: val_loss improved from 0.25352 to 0.25087, saving model to models/model8.hdf5
#  - 15s - loss: 0.2182 - get_f1: 0.9347 - val_loss: 0.2509 - val_get_f1: 0.9163
# Epoch 27/100
#
# Epoch 00027: val_loss improved from 0.25087 to 0.24843, saving model to models/model8.hdf5
#  - 15s - loss: 0.2149 - get_f1: 0.9356 - val_loss: 0.2484 - val_get_f1: 0.9164
# Epoch 28/100
#
# Epoch 00028: val_loss improved from 0.24843 to 0.24617, saving model to models/model8.hdf5
#  - 15s - loss: 0.2109 - get_f1: 0.9376 - val_loss: 0.2462 - val_get_f1: 0.9161
# Epoch 29/100
#
# Epoch 00029: val_loss improved from 0.24617 to 0.24401, saving model to models/model8.hdf5
#  - 14s - loss: 0.2072 - get_f1: 0.9385 - val_loss: 0.2440 - val_get_f1: 0.9162
# Epoch 30/100
#
# Epoch 00030: val_loss improved from 0.24401 to 0.24213, saving model to models/model8.hdf5
#  - 14s - loss: 0.2040 - get_f1: 0.9396 - val_loss: 0.2421 - val_get_f1: 0.9170
# Epoch 31/100
#
# Epoch 00031: val_loss improved from 0.24213 to 0.24025, saving model to models/model8.hdf5
#  - 14s - loss: 0.2010 - get_f1: 0.9401 - val_loss: 0.2403 - val_get_f1: 0.9164
# Epoch 32/100
#
# Epoch 00032: val_loss improved from 0.24025 to 0.23856, saving model to models/model8.hdf5
#  - 14s - loss: 0.1977 - get_f1: 0.9420 - val_loss: 0.2386 - val_get_f1: 0.9156
# Epoch 33/100
#
# Epoch 00033: val_loss improved from 0.23856 to 0.23699, saving model to models/model8.hdf5
#  - 14s - loss: 0.1953 - get_f1: 0.9418 - val_loss: 0.2370 - val_get_f1: 0.9176
# Epoch 34/100
#
# Epoch 00034: val_loss improved from 0.23699 to 0.23549, saving model to models/model8.hdf5
#  - 14s - loss: 0.1914 - get_f1: 0.9436 - val_loss: 0.2355 - val_get_f1: 0.9183
# Epoch 35/100
#
# Epoch 00035: val_loss improved from 0.23549 to 0.23409, saving model to models/model8.hdf5
#  - 14s - loss: 0.1903 - get_f1: 0.9441 - val_loss: 0.2341 - val_get_f1: 0.9184
# Epoch 36/100
#
# Epoch 00036: val_loss improved from 0.23409 to 0.23278, saving model to models/model8.hdf5
#  - 14s - loss: 0.1873 - get_f1: 0.9445 - val_loss: 0.2328 - val_get_f1: 0.9182
# Epoch 37/100
#
# Epoch 00037: val_loss improved from 0.23278 to 0.23151, saving model to models/model8.hdf5
#  - 14s - loss: 0.1845 - get_f1: 0.9464 - val_loss: 0.2315 - val_get_f1: 0.9193
# Epoch 38/100
#
# Epoch 00038: val_loss improved from 0.23151 to 0.23036, saving model to models/model8.hdf5
#  - 14s - loss: 0.1823 - get_f1: 0.9465 - val_loss: 0.2304 - val_get_f1: 0.9197
# Epoch 39/100
#
# Epoch 00039: val_loss improved from 0.23036 to 0.22929, saving model to models/model8.hdf5
#  - 14s - loss: 0.1795 - get_f1: 0.9470 - val_loss: 0.2293 - val_get_f1: 0.9187
# Epoch 40/100
#
# Epoch 00040: val_loss improved from 0.22929 to 0.22832, saving model to models/model8.hdf5
#  - 14s - loss: 0.1781 - get_f1: 0.9465 - val_loss: 0.2283 - val_get_f1: 0.9203
# Epoch 41/100
#
# Epoch 00041: val_loss improved from 0.22832 to 0.22728, saving model to models/model8.hdf5
#  - 14s - loss: 0.1755 - get_f1: 0.9486 - val_loss: 0.2273 - val_get_f1: 0.9179
# Epoch 42/100
#
# Epoch 00042: val_loss improved from 0.22728 to 0.22643, saving model to models/model8.hdf5
#  - 15s - loss: 0.1741 - get_f1: 0.9489 - val_loss: 0.2264 - val_get_f1: 0.9188
# Epoch 43/100
#
# Epoch 00043: val_loss improved from 0.22643 to 0.22554, saving model to models/model8.hdf5
#  - 15s - loss: 0.1727 - get_f1: 0.9493 - val_loss: 0.2255 - val_get_f1: 0.9182
# Epoch 44/100
#
# Epoch 00044: val_loss improved from 0.22554 to 0.22475, saving model to models/model8.hdf5
#  - 14s - loss: 0.1697 - get_f1: 0.9505 - val_loss: 0.2247 - val_get_f1: 0.9185
# Epoch 45/100
#
# Epoch 00045: val_loss improved from 0.22475 to 0.22398, saving model to models/model8.hdf5
#  - 14s - loss: 0.1691 - get_f1: 0.9507 - val_loss: 0.2240 - val_get_f1: 0.9187
# Epoch 46/100
#
# Epoch 00046: val_loss improved from 0.22398 to 0.22328, saving model to models/model8.hdf5
#  - 15s - loss: 0.1656 - get_f1: 0.9520 - val_loss: 0.2233 - val_get_f1: 0.9191
# Epoch 47/100
#
# Epoch 00047: val_loss improved from 0.22328 to 0.22261, saving model to models/model8.hdf5
#  - 15s - loss: 0.1646 - get_f1: 0.9518 - val_loss: 0.2226 - val_get_f1: 0.9170
# Epoch 48/100
#
# Epoch 00048: val_loss improved from 0.22261 to 0.22196, saving model to models/model8.hdf5
#  - 14s - loss: 0.1623 - get_f1: 0.9537 - val_loss: 0.2220 - val_get_f1: 0.9195
# Epoch 49/100
#
# Epoch 00049: val_loss improved from 0.22196 to 0.22138, saving model to models/model8.hdf5
#  - 14s - loss: 0.1612 - get_f1: 0.9532 - val_loss: 0.2214 - val_get_f1: 0.9190
# Epoch 50/100
#
# Epoch 00050: val_loss improved from 0.22138 to 0.22091, saving model to models/model8.hdf5
#  - 14s - loss: 0.1596 - get_f1: 0.9533 - val_loss: 0.2209 - val_get_f1: 0.9194
# Epoch 51/100
#
# Epoch 00051: val_loss improved from 0.22091 to 0.22030, saving model to models/model8.hdf5
#  - 15s - loss: 0.1582 - get_f1: 0.9540 - val_loss: 0.2203 - val_get_f1: 0.9192
# Epoch 52/100
#
# Epoch 00052: val_loss improved from 0.22030 to 0.21992, saving model to models/model8.hdf5
#  - 14s - loss: 0.1560 - get_f1: 0.9557 - val_loss: 0.2199 - val_get_f1: 0.9190
# Epoch 53/100
#
# Epoch 00053: val_loss improved from 0.21992 to 0.21942, saving model to models/model8.hdf5
#  - 14s - loss: 0.1548 - get_f1: 0.9553 - val_loss: 0.2194 - val_get_f1: 0.9196
# Epoch 54/100
#
# Epoch 00054: val_loss improved from 0.21942 to 0.21895, saving model to models/model8.hdf5
#  - 15s - loss: 0.1530 - get_f1: 0.9559 - val_loss: 0.2190 - val_get_f1: 0.9188
# Epoch 55/100
#
# Epoch 00055: val_loss improved from 0.21895 to 0.21853, saving model to models/model8.hdf5
#  - 15s - loss: 0.1514 - get_f1: 0.9573 - val_loss: 0.2185 - val_get_f1: 0.9196
# Epoch 56/100
#
# Epoch 00056: val_loss improved from 0.21853 to 0.21814, saving model to models/model8.hdf5
#  - 16s - loss: 0.1502 - get_f1: 0.9580 - val_loss: 0.2181 - val_get_f1: 0.9187
# Epoch 57/100
#
# Epoch 00057: val_loss improved from 0.21814 to 0.21787, saving model to models/model8.hdf5
#  - 15s - loss: 0.1492 - get_f1: 0.9580 - val_loss: 0.2179 - val_get_f1: 0.9204
# Epoch 58/100
#
# Epoch 00058: val_loss improved from 0.21787 to 0.21753, saving model to models/model8.hdf5
#  - 15s - loss: 0.1483 - get_f1: 0.9579 - val_loss: 0.2175 - val_get_f1: 0.9200
# Epoch 59/100
#
# Epoch 00059: val_loss improved from 0.21753 to 0.21720, saving model to models/model8.hdf5
#  - 16s - loss: 0.1472 - get_f1: 0.9599 - val_loss: 0.2172 - val_get_f1: 0.9196
# Epoch 60/100
#
# Epoch 00060: val_loss improved from 0.21720 to 0.21696, saving model to models/model8.hdf5
#  - 15s - loss: 0.1447 - get_f1: 0.9595 - val_loss: 0.2170 - val_get_f1: 0.9204
# Epoch 61/100
#
# Epoch 00061: val_loss improved from 0.21696 to 0.21663, saving model to models/model8.hdf5
#  - 15s - loss: 0.1437 - get_f1: 0.9599 - val_loss: 0.2166 - val_get_f1: 0.9178
# Epoch 62/100
#
# Epoch 00062: val_loss improved from 0.21663 to 0.21640, saving model to models/model8.hdf5
#  - 15s - loss: 0.1424 - get_f1: 0.9604 - val_loss: 0.2164 - val_get_f1: 0.9185
# Epoch 63/100
#
# Epoch 00063: val_loss improved from 0.21640 to 0.21611, saving model to models/model8.hdf5
#  - 15s - loss: 0.1420 - get_f1: 0.9604 - val_loss: 0.2161 - val_get_f1: 0.9198
# Epoch 64/100
#
# Epoch 00064: val_loss improved from 0.21611 to 0.21587, saving model to models/model8.hdf5
#  - 14s - loss: 0.1402 - get_f1: 0.9615 - val_loss: 0.2159 - val_get_f1: 0.9184
# Epoch 65/100
#
# Epoch 00065: val_loss improved from 0.21587 to 0.21567, saving model to models/model8.hdf5
#  - 14s - loss: 0.1386 - get_f1: 0.9626 - val_loss: 0.2157 - val_get_f1: 0.9190
# Epoch 66/100
#
# Epoch 00066: val_loss improved from 0.21567 to 0.21541, saving model to models/model8.hdf5
#  - 14s - loss: 0.1370 - get_f1: 0.9631 - val_loss: 0.2154 - val_get_f1: 0.9191
# Epoch 67/100
#
# Epoch 00067: val_loss improved from 0.21541 to 0.21527, saving model to models/model8.hdf5
#  - 14s - loss: 0.1372 - get_f1: 0.9613 - val_loss: 0.2153 - val_get_f1: 0.9210
# Epoch 68/100
#
# Epoch 00068: val_loss improved from 0.21527 to 0.21512, saving model to models/model8.hdf5
#  - 14s - loss: 0.1356 - get_f1: 0.9638 - val_loss: 0.2151 - val_get_f1: 0.9193
# Epoch 69/100
#
# Epoch 00069: val_loss improved from 0.21512 to 0.21495, saving model to models/model8.hdf5
#  - 15s - loss: 0.1346 - get_f1: 0.9627 - val_loss: 0.2149 - val_get_f1: 0.9186
# Epoch 70/100
#
# Epoch 00070: val_loss improved from 0.21495 to 0.21484, saving model to models/model8.hdf5
#  - 14s - loss: 0.1335 - get_f1: 0.9644 - val_loss: 0.2148 - val_get_f1: 0.9192
# Epoch 71/100
#
# Epoch 00071: val_loss improved from 0.21484 to 0.21474, saving model to models/model8.hdf5
#  - 15s - loss: 0.1325 - get_f1: 0.9637 - val_loss: 0.2147 - val_get_f1: 0.9199
# Epoch 72/100
#
# Epoch 00072: val_loss improved from 0.21474 to 0.21461, saving model to models/model8.hdf5
#  - 15s - loss: 0.1319 - get_f1: 0.9642 - val_loss: 0.2146 - val_get_f1: 0.9176
# Epoch 73/100
#
# Epoch 00073: val_loss improved from 0.21461 to 0.21455, saving model to models/model8.hdf5
#  - 15s - loss: 0.1306 - get_f1: 0.9647 - val_loss: 0.2145 - val_get_f1: 0.9191
# Epoch 74/100
#
# Epoch 00074: val_loss improved from 0.21455 to 0.21445, saving model to models/model8.hdf5
#  - 15s - loss: 0.1298 - get_f1: 0.9652 - val_loss: 0.2145 - val_get_f1: 0.9183
# Epoch 75/100
#
# Epoch 00075: val_loss improved from 0.21445 to 0.21435, saving model to models/model8.hdf5
#  - 15s - loss: 0.1280 - get_f1: 0.9652 - val_loss: 0.2144 - val_get_f1: 0.9188
# Epoch 76/100
#
# Epoch 00076: val_loss improved from 0.21435 to 0.21424, saving model to models/model8.hdf5
#  - 15s - loss: 0.1275 - get_f1: 0.9656 - val_loss: 0.2142 - val_get_f1: 0.9196
# Epoch 77/100
#
# Epoch 00077: val_loss improved from 0.21424 to 0.21424, saving model to models/model8.hdf5
#  - 15s - loss: 0.1271 - get_f1: 0.9649 - val_loss: 0.2142 - val_get_f1: 0.9197
# Epoch 78/100
#
# Epoch 00078: val_loss improved from 0.21424 to 0.21416, saving model to models/model8.hdf5
#  - 16s - loss: 0.1256 - get_f1: 0.9662 - val_loss: 0.2142 - val_get_f1: 0.9215
# Epoch 79/100
#
# Epoch 00079: val_loss did not improve from 0.21416
#  - 15s - loss: 0.1241 - get_f1: 0.9674 - val_loss: 0.2142 - val_get_f1: 0.9188
# Epoch 80/100
#
# Epoch 00080: val_loss improved from 0.21416 to 0.21414, saving model to models/model8.hdf5
#  - 15s - loss: 0.1239 - get_f1: 0.9682 - val_loss: 0.2141 - val_get_f1: 0.9200
# Epoch 81/100
#
# Epoch 00081: val_loss improved from 0.21414 to 0.21410, saving model to models/model8.hdf5
#  - 15s - loss: 0.1234 - get_f1: 0.9665 - val_loss: 0.2141 - val_get_f1: 0.9201
# Epoch 82/100
#
# Epoch 00082: val_loss improved from 0.21410 to 0.21404, saving model to models/model8.hdf5
#  - 15s - loss: 0.1217 - get_f1: 0.9681 - val_loss: 0.2140 - val_get_f1: 0.9197
# Epoch 83/100
#
# Epoch 00083: val_loss did not improve from 0.21404
#  - 14s - loss: 0.1213 - get_f1: 0.9679 - val_loss: 0.2140 - val_get_f1: 0.9198
# Epoch 84/100
#
# Epoch 00084: val_loss did not improve from 0.21404
#  - 14s - loss: 0.1201 - get_f1: 0.9693 - val_loss: 0.2141 - val_get_f1: 0.9199
# Epoch 85/100
#
# Epoch 00085: val_loss improved from 0.21404 to 0.21404, saving model to models/model8.hdf5
#  - 14s - loss: 0.1193 - get_f1: 0.9692 - val_loss: 0.2140 - val_get_f1: 0.9191
# Epoch 86/100
#
# Epoch 00086: val_loss improved from 0.21404 to 0.21401, saving model to models/model8.hdf5
#  - 14s - loss: 0.1183 - get_f1: 0.9691 - val_loss: 0.2140 - val_get_f1: 0.9195
# Epoch 87/100
#
# Epoch 00087: val_loss did not improve from 0.21401
#  - 14s - loss: 0.1185 - get_f1: 0.9683 - val_loss: 0.2141 - val_get_f1: 0.9193
# Epoch 88/100
#
# Epoch 00088: val_loss did not improve from 0.21401
#  - 14s - loss: 0.1175 - get_f1: 0.9689 - val_loss: 0.2141 - val_get_f1: 0.9186
# Epoch 89/100
#
# Epoch 00089: val_loss did not improve from 0.21401
#  - 14s - loss: 0.1162 - get_f1: 0.9700 - val_loss: 0.2142 - val_get_f1: 0.9200
